# %%
import pandas as pd
import re

# %% [markdown]
# ## Metadata of patches
# Our pipeline accepts svs at a time so to avoid overwritting in the process_list_autogen.csv, we are creating our own list

# %%
# import pandas as pd

# # Hardcoded column names
# columns = [
#     'slide_id', 'process' ,'status','seg_level', 'sthresh', 'mthresh', 'close', 'use_otsu',
#     'keep_ids', 'exclude_ids', 'a_t', 'a_h', 'max_n_holes','vis_level','line_thickness',
#     'use_padding', 'contour_fn'
# ]

# # Create empty DataFrame with only headers
# df = pd.DataFrame(columns=columns)

# # Save to CSV
# df.to_csv("./FLAT_DIRECTORY/process_list_final.csv", index=False)

# %%
# import pandas as pd

# # Hardcoded column names
# columns = [
#     'slide_id', 'process' ,'status','seg_level', 'sthresh', 'mthresh', 'close', 'use_otsu',
#     'keep_ids', 'exclude_ids', 'a_t', 'a_h', 'max_n_holes','vis_level','line_thickness',
#     'use_padding', 'contour_fn'
# ]

# # Create empty DataFrame with only headers
# df = pd.DataFrame(columns=columns)

# # Save to CSV
# df.to_csv("./FLAT_DIRECTORY/process_list_autogen.csv", index=False)

# %%
# import pandas as pd

# # Hardcoded column names
# columns = [
#     'svs_file','renamed_file'
# ]

# # Create empty DataFrame with only headers
# df = pd.DataFrame(columns=columns)

# # Save to CSV
# df.to_csv("./FLAT_DIRECTORY/file_names.csv", index=False)

# %%
def is_valid_svs_file(filename, excel_path="PatientsSheet.xlsx", columnNumb=0):
    """
    Check if a given .svs filename is valid based on:
    - Matching first 12 characters with patient ID in Excel column 0.
    - Patient's label in specified column is not NaN or empty.

    Args:
        filename (str): Filename to check (should end in .svs).
        excel_path (str): Path to the Excel sheet.
        columnNumb (int): Column number to check for the label (default: 1 for MSI).

    Returns:
        tuple: (bool, value) where bool is True if valid, False otherwise,
               and value is the label from the specified column or None if invalid.
    """
    # Check if filename ends with .svs
    if not filename.lower().endswith('.svs'):
        print(f"Error: Filename '{filename}' does not end with .svs")
        return False, None

    # Check if filename is long enough to extract patient ID
    if len(filename) < 12:
        print(f"Error: Filename '{filename}' is too short (less than 12 characters)")
        return False, None

    # Extract patient ID from first 12 characters
    patient_id = filename[:12]

    try:
        # Read Excel file
        df = pd.read_excel(excel_path, header=None)
    except FileNotFoundError:
        print(f"Error: Excel file '{excel_path}' not found.")
        return False, None
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        return False, None

    # Check if DataFrame is empty
    if df.empty:
        print("Error: Excel file is empty.")
        return False, None

    # Handle headers - skip first row if it contains "PATIENTS"
    if len(df) > 0 and str(df.iloc[0, 0]).strip().upper() == "PATIENTS":
        df = df.iloc[1:]

    # Check if we have data after potential header removal
    if df.empty:
        print("Error: No data found after header processing.")
        return False, None

    # Ensure we have enough columns (at least columnNumb + 1 since it's 0-indexed)
    required_columns = max(1, columnNumb + 1)  # At least 1 column, or columnNumb + 1
    if df.shape[1] < required_columns:
        print(f"Error: Excel file must have at least {required_columns} columns. "
              f"Found {df.shape[1]} columns. Cannot access column {columnNumb}.")
        return False, None

    # Clean and standardize patient ID column (always column 0)
    df.iloc[:, 0] = df.iloc[:, 0].astype(str).str.strip()
    
    # Clean and standardize the target column
    df.iloc[:, columnNumb] = df.iloc[:, columnNumb].astype(str).str.strip()

    # Filter for this patient
    match = df[df.iloc[:, 0] == patient_id]

    if match.empty:
        print(f"Patient ID '{patient_id}' not found in Excel file.")
        return False, None

    # Check label validity in specified column
    label = match.iloc[0, columnNumb]
    if pd.isna(label) or str(label).strip().lower() in ['nan', '', 'none']:
        print(f"Patient '{patient_id}' has invalid or empty label in column {columnNumb}: '{label}'")
        return False, None

    print(f"Valid file: Patient '{patient_id}' found with label in column {columnNumb}: '{label}'")
    return True, label

# %% [markdown]
# ## Renaming files to patientid and label
# Clam on default give name of svs to .h5 file so we are renaming our .h5 file to 12 char of .svs file with label

# %%
def rename_h5_file(svs_filename, label, h5_dir):
    base_name = os.path.splitext(os.path.basename(svs_filename))[0]
    old_h5_path = os.path.join(h5_dir, f"{base_name}.h5")
    new_base = f"{base_name[:12]}_{label}.h5"
    new_h5_path = os.path.join(h5_dir, new_base)

    if os.path.exists(old_h5_path):
        try:
            os.rename(old_h5_path, new_h5_path)
            print(f"📦 Renamed H5: {old_h5_path} → {new_h5_path}")
        except FileExistsError:
            print(f"⚠️ File already exists: {new_h5_path}. Skipping rename.")
    else:
        print(f"❌ File not found: {old_h5_path}")

    return new_h5_path

# %% [markdown]
# ## Patch creation function

# %%
import os
import re
import numpy as np
import pandas as pd
from PIL import Image
import h5py
import openslide

def create_patches_from_h5(h5_path, svs_path, output_dir, magnification):
    base_name = os.path.splitext(os.path.basename(h5_path))[0]
    metadatadir= r"D:\Aamir Gulzar\KSA_project2\dataset\patches_metadata"
    os.makedirs(metadatadir, exist_ok=True)

    # If output_dir already exists, skip patch creation and rebuild metadata from PNGs
    if os.path.exists(output_dir) and os.path.isdir(output_dir):
        print(f"⚠️ Output directory '{output_dir}' already exists. Rebuilding metadata from existing PNGs...")

        metadata = []
        pattern = re.compile(rf"{re.escape(base_name)}_x(\d+)_y(\d+)_patch(\d{{5}})\.png")

        for filename in sorted(os.listdir(output_dir)):
            if filename.endswith(".png") and filename.startswith(base_name):
                match = pattern.match(filename)
                if not match:
                    print(f"⚠️ Skipping unrecognized filename: {filename}")
                    continue

                x, y, patch_number = map(int, match.groups())
                patch_path = os.path.join(output_dir, filename)

                try:
                    patch = Image.open(patch_path).convert('RGB')
                    rgb_array = np.array(patch)
                    avg_r, avg_g, avg_b = rgb_array.mean(axis=(0, 1))
                    std_r, std_g, std_b = rgb_array.std(axis=(0, 1))

                    metadata.append({
                        'patch_location': patch_path,
                        'patch_name': filename,
                        'patch_number': patch_number,
                        'patch_x': x,
                        'patch_y': y,
                        'avg_R': round(avg_r, 2),
                        'avg_G': round(avg_g, 2),
                        'avg_B': round(avg_b, 2),
                        'std_R': round(std_r, 2),
                        'std_G': round(std_g, 2),
                        'std_B': round(std_b, 2)
                    })
                except Exception as e:
                    print(f"❌ Failed to process {filename}: {e}")

        # Save CSV
        csv_path = os.path.join(metadatadir, f"{base_name}.csv")
        df = pd.DataFrame(metadata)
        df.to_csv(csv_path, index=False)

        print(f"📄 Metadata CSV rebuilt and saved to: {csv_path}")
        return

    # Otherwise, proceed with normal patch extraction
    os.makedirs(output_dir)

    # Set patch size
    if magnification == 40:
        PATCH_SIZE = 1024
        FINAL_SIZE = 512
    elif magnification == 20:
        PATCH_SIZE = 512
        FINAL_SIZE = 512
    else:
        raise ValueError(f"Unsupported magnification: {magnification}")

    # Load coordinates
    with h5py.File(h5_path, 'r') as h5_file:
        coords = h5_file['coords'][:]

    slide = openslide.OpenSlide(svs_path)
    metadata = []

    for i, (x, y) in enumerate(coords):
        patch = slide.read_region((int(x), int(y)), 0, (PATCH_SIZE, PATCH_SIZE)).convert('RGB')

        if PATCH_SIZE != FINAL_SIZE:
            patch = patch.resize((FINAL_SIZE, FINAL_SIZE), resample=Image.BICUBIC)
            x = int(x) // 2
            y = int(y) // 2
        else:
            x = int(x)
            y = int(y)

        patch_name = f"{base_name}_x{x}_y{y}_patch{i:05d}.png"
        patch_path = os.path.join(output_dir, patch_name)
        patch.save(patch_path)

        rgb_array = np.array(patch)
        avg_r, avg_g, avg_b = rgb_array.mean(axis=(0, 1))
        std_r, std_g, std_b = rgb_array.std(axis=(0, 1))

        metadata.append({
            'patch_location': patch_path,
            'patch_name': patch_name,
            'patch_number': i,
            'patch_x': x,
            'patch_y': y,
            'avg_R': round(avg_r, 2),
            'avg_G': round(avg_g, 2),
            'avg_B': round(avg_b, 2),
            'std_R': round(std_r, 2),
            'std_G': round(std_g, 2),
            'std_B': round(std_b, 2)
        })

    # Save metadata CSV
    csv_path = os.path.join(metadatadir, f"{base_name}.csv")
    df = pd.DataFrame(metadata)
    df.to_csv(csv_path, index=False)

    print(f"✅ Done! Saved {len(coords)} patches to {output_dir}")
    print(f"📄 Metadata CSV saved to: {csv_path}")

# %% [markdown]
# ## Comparing to the slidelog metadata file

# %%
import os
import pandas as pd

def check_svs_file(svs_file, excel_file, filename_column="Filename", label_column="Label"):
    try:
        df = pd.read_csv(excel_file)

        filename = svs_file
        row = df[df[filename_column] == filename]

        if not row.empty:
            label = row.iloc[0][label_column]
            return True, label
        else:
            return False, None

    except Exception as e:
        print(f"Error reading Excel or processing file: {e}")
        return False, None

# %% [markdown]
# ## Pipeline

# %%
import os

# Directory path
directory = r'D:\Aamir Gulzar\KSA_project2\dataset\patch_data'

# Get list of folders only (not files)
folder_names = [name for name in os.listdir(directory) if os.path.isdir(os.path.join(directory, name))]

print(f"Total folders found: {len(folder_names)}")
print(folder_names)
# Out:
# Total folders found: 418
# ['TCGA-3L-AA1B_nonMSIH', 'TCGA-4N-A93T_nonMSIH', 'TCGA-5M-AAT4_nonMSIH', 'TCGA-5M-AAT6_MSIH', 'TCGA-5M-AATE_nonMSIH', 'TCGA-A6-2671_nonMSIH', 'TCGA-A6-2681_nonMSIH', 'TCGA-A6-2685_nonMSIH', 'TCGA-A6-2686_MSIH', 'TCGA-A6-3807_nonMSIH', 'TCGA-A6-4105_nonMSIH', 'TCGA-A6-4107_nonMSIH', 'TCGA-A6-5657_nonMSIH', 'TCGA-A6-5660_nonMSIH', 'TCGA-A6-5661_MSIH', 'TCGA-A6-5662_nonMSIH', 'TCGA-A6-5664_nonMSIH', 'TCGA-A6-5665_MSIH', 'TCGA-A6-5666_nonMSIH', 'TCGA-A6-5667_nonMSIH', 'TCGA-A6-6137_nonMSIH', 'TCGA-A6-6138_nonMSIH', 'TCGA-A6-6142_nonMSIH', 'TCGA-A6-6648_nonMSIH', 'TCGA-A6-6649_nonMSIH', 'TCGA-A6-6651_nonMSIH', 'TCGA-A6-6652_nonMSIH', 'TCGA-A6-6653_MSIH', 'TCGA-A6-6654_nonMSIH', 'TCGA-A6-A565_nonMSIH', 'TCGA-A6-A566_nonMSIH', 'TCGA-A6-A567_nonMSIH', 'TCGA-A6-A56B_nonMSIH', 'TCGA-AA-3664_nonMSIH', 'TCGA-AA-3666_nonMSIH', 'TCGA-AA-3667_nonMSIH', 'TCGA-AA-3673_nonMSIH', 'TCGA-AA-3678_nonMSIH', 'TCGA-AA-3679_nonMSIH', 'TCGA-AA-3680_nonMSIH', 'TCGA-AA-3681_nonMSIH', 'TCGA-AA-3684_nonMSIH', 'TCGA-AA-3688_nonMSIH', 'TCGA-AA-3692_nonMSIH', 'TCGA-AA-3693_nonMSIH', 'TCGA-AA-3696_nonMSIH', 'TCGA-AA-3715_MSIH', 'TCGA-AA-3811_MSIH', 'TCGA-AA-3812_nonMSIH', 'TCGA-AA-3814_nonMSIH', 'TCGA-AA-3818_nonMSIH', 'TCGA-AA-3819_nonMSIH', 'TCGA-AA-3821_MSIH', 'TCGA-AA-3831_nonMSIH', 'TCGA-AA-3833_MSIH', 'TCGA-AA-3837_nonMSIH', 'TCGA-AA-3842_nonMSIH', 'TCGA-AA-3844_nonMSIH', 'TCGA-AA-3845_MSIH', 'TCGA-AA-3846_nonMSIH', 'TCGA-AA-3848_nonMSIH', 'TCGA-AA-3850_nonMSIH', 'TCGA-AA-3851_nonMSIH', 'TCGA-AA-3852_nonMSIH', 'TCGA-AA-3854_nonMSIH', 'TCGA-AA-3855_nonMSIH', 'TCGA-AA-3856_nonMSIH', 'TCGA-AA-3858_nonMSIH', 'TCGA-AA-3864_MSIH', 'TCGA-AA-3866_nonMSIH', 'TCGA-AA-3867_nonMSIH', 'TCGA-AA-3875_nonMSIH', 'TCGA-AA-3877_MSIH', 'TCGA-AA-3947_MSIH', 'TCGA-AA-3949_MSIH', 'TCGA-AA-3950_MSIH', 'TCGA-AA-3952_nonMSIH', 'TCGA-AA-3956_nonMSIH', 'TCGA-AA-3966_MSIH', 'TCGA-AA-3968_nonMSIH', 'TCGA-AA-3971_nonMSIH', 'TCGA-AA-3973_nonMSIH', 'TCGA-AA-3975_nonMSIH', 'TCGA-AA-3976_nonMSIH', 'TCGA-AA-3979_nonMSIH', 'TCGA-AA-3982_nonMSIH', 'TCGA-AA-3984_nonMSIH', 'TCGA-AA-3986_nonMSIH', 'TCGA-AA-3989_nonMSIH', 'TCGA-AA-3994_nonMSIH', 'TCGA-AA-A010_nonMSIH', 'TCGA-AA-A01P_MSIH', 'TCGA-AA-A01R_MSIH', 'TCGA-AA-A01S_nonMSIH', 'TCGA-AA-A01T_nonMSIH', 'TCGA-AA-A01V_nonMSIH', 'TCGA-AA-A01X_nonMSIH', 'TCGA-AA-A01Z_nonMSIH', 'TCGA-AA-A024_nonMSIH', 'TCGA-AA-A02E_nonMSIH', 'TCGA-AA-A02F_nonMSIH', 'TCGA-AA-A02H_nonMSIH', 'TCGA-AA-A02O_nonMSIH', 'TCGA-AA-A02Y_nonMSIH', 'TCGA-AA-A03F_nonMSIH', 'TCGA-AA-A03J_nonMSIH', 'TCGA-AD-5900_MSIH', 'TCGA-AD-6548_nonMSIH', 'TCGA-AD-6888_nonMSIH', 'TCGA-AD-6889_MSIH', 'TCGA-AD-6890_nonMSIH', 'TCGA-AD-6901_nonMSIH', 'TCGA-AD-6963_nonMSIH', 'TCGA-AD-6964_MSIH', 'TCGA-AD-6965_nonMSIH', 'TCGA-AD-A5EJ_MSIH', 'TCGA-AD-A5EK_nonMSIH', 'TCGA-AF-2687_nonMSIH', 'TCGA-AF-2690_nonMSIH', 'TCGA-AF-2693_nonMSIH', 'TCGA-AF-3911_nonMSIH', 'TCGA-AF-4110_nonMSIH', 'TCGA-AF-6136_nonMSIH', 'TCGA-AF-6655_nonMSIH', 'TCGA-AF-6672_nonMSIH', 'TCGA-AF-A56K_nonMSIH', 'TCGA-AF-A56L_nonMSIH', 'TCGA-AF-A56N_nonMSIH', 'TCGA-AG-3726_nonMSIH', 'TCGA-AG-3727_nonMSIH', 'TCGA-AG-3878_nonMSIH', 'TCGA-AG-3882_nonMSIH', 'TCGA-AG-3883_nonMSIH', 'TCGA-AG-3885_nonMSIH', 'TCGA-AG-3887_nonMSIH', 'TCGA-AG-3890_nonMSIH', 'TCGA-AG-3892_nonMSIH', 'TCGA-AG-3893_nonMSIH', 'TCGA-AG-3894_nonMSIH', 'TCGA-AG-3896_nonMSIH', 'TCGA-AG-3898_nonMSIH', 'TCGA-AG-3901_nonMSIH', 'TCGA-AG-3902_nonMSIH', 'TCGA-AG-3909_nonMSIH', 'TCGA-AG-4001_nonMSIH', 'TCGA-AG-4008_nonMSIH', 'TCGA-AG-4015_nonMSIH', 'TCGA-AG-4021_nonMSIH', 'TCGA-AG-4022_nonMSIH', 'TCGA-AG-A002_nonMSIH', 'TCGA-AG-A008_nonMSIH', 'TCGA-AG-A00C_nonMSIH', 'TCGA-AG-A011_nonMSIH', 'TCGA-AG-A015_nonMSIH', 'TCGA-AG-A016_nonMSIH', 'TCGA-AG-A01L_nonMSIH', 'TCGA-AG-A01N_nonMSIH', 'TCGA-AG-A01W_nonMSIH', 'TCGA-AG-A01Y_nonMSIH', 'TCGA-AG-A020_nonMSIH', 'TCGA-AG-A026_nonMSIH', 'TCGA-AG-A02N_MSIH', 'TCGA-AG-A02X_nonMSIH', 'TCGA-AH-6544_nonMSIH', 'TCGA-AH-6547_nonMSIH', 'TCGA-AH-6643_nonMSIH', 'TCGA-AH-6644_nonMSIH', 'TCGA-AH-6897_nonMSIH', 'TCGA-AH-6903_nonMSIH', 'TCGA-AM-582 ...

# %%
import os
import subprocess
from pathlib import Path
import openslide

# Top-level directory containing subfolders with .svs files
wsi_root = "D:/Aamir Gulzar/WSI_Raw_data"
flat_dir = r"D:\Aamir Gulzar\KSA_project2\dataset\Flat_directory"
count = 0
root_dir = r"D:\Aamir Gulzar\KSA_project2\dataset\patch_data"

# Get all subdirectories
subfolders = [f.name for f in os.scandir(root_dir) if f.is_dir()]

# Loop through all subfolders
for subdir in os.listdir(wsi_root):
    # if count == 2:
    #     break
    count += 1
    print(f"Count: {count}")
    
    full_subdir_path = os.path.join(wsi_root, subdir)
    if not os.path.isdir(full_subdir_path):
        continue  # Skip non-folder items

    # Search for .svs file in this subfolder
    svs_files = [f for f in os.listdir(full_subdir_path) if f.endswith('.svs')]
    if not svs_files:
        print(f"❌ No .svs file found in: {full_subdir_path}")
        continue
    # else:
    #     print(f"🔍 Found .svs files in {subdir}: {svs_files}")

    # If multiple .svs files exist, process each one
    for svs_file in svs_files:
        print(f"\n🚀 Starting processing of: {svs_file} in folder: {subdir}")

        # Validate SVS against metadata
        bool_valid, label = check_svs_file(
            svs_file,
            "./slides_metadata/slide_metadata_filtered.csv",
            filename_column="Filename",
            label_column="Label"
        )

        newnameofsvs = f"{svs_file[:12]}_{label}"

        if newnameofsvs in folder_names:
            print("File already exists")
            break

        if not bool_valid:
            print(f"⚠️ Skipping {svs_file}: Not found or invalid in metadata.")
            continue
        else:
            print(f"✅ Valid SVS: {svs_file} | Label: {label}")

        source_dir = full_subdir_path
        source_dir_quoted = f"{source_dir}"
        flat_dir_quoted = f"{flat_dir}"

        # output_dir = "./FLAT_DIRECTORY/downsampled"
        svs_path = os.path.join(source_dir_quoted, svs_file)

        try:
            slide = openslide.OpenSlide(svs_path)
        except Exception as e:
            print(f"❌ Error opening slide {svs_file}: {e}")
            continue

        # Print magnification and spacing
        mag = int(slide.properties.get("openslide.objective-power", 20))
        spacing = slide.properties.get("openslide.mpp-x", "Unknown")
        print(f"🔬 Magnification: {mag}x")
        print(f"📏 Spacing (mpp-x): {spacing}")

        # Set patch and step size
        if mag == 40:
            print("📐 Using patch/step size of 1024 (40x)")
            patch_size = '1024'
            step_size = '1024'
        else:
            print("📐 Using patch/step size of 512 (20x)")
            patch_size = '512'
            step_size = '512'

        
        # Construct command
        command = [
            'python', './CLAM/create_patches_fp.py',
            '--source', source_dir_quoted,
            '--save_dir', flat_dir,
            '--patch_size', patch_size,
            '--step_size', step_size,
            '--seg', '--patch'
        ]
        print("📦 Running patch creation script...")

        with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
            for line in proc.stdout:
                print(line, end='')  # Stream live output

        # Rename .h5 file and log it
        h5directory= r"D:\Aamir Gulzar\KSA_project2\dataset\Flat_directory\patches"
        new_h5_path = rename_h5_file(svs_file, label, h5_dir=h5directory)
        print(f"📄 Renamed .h5 file path: {new_h5_path}")

        # Set patch output directory
        base_dir = "D:/Aamir Gulzar/KSA_project2/dataset/patch_data"
        sub_dir = f"{svs_file[:12]}_{label}"
        output_dir = os.path.join(base_dir, sub_dir)

        # Determine skipped patches file path
        svs_base_filename = os.path.splitext(os.path.basename(svs_file))[0]
        skipped_filename = f"{svs_base_filename}skipped_patches.csv"
        full_skipped_path = Path("./FLAT_DIRECTORY/patches/") / skipped_filename

        # Run patch extraction from .h5
        print(f"🧩 Extracting image patches to: {output_dir}")
        create_patches_from_h5(new_h5_path, svs_path, output_dir, mag)
        print(f"✅ Finished processing {svs_file}")
# Out:
# Count: 1
#
# 🚀 Starting processing of: TCGA-A6-2686-01Z-00-DX1.0540a027-2a0c-46c7-9af0-7b8672631de7.svs in folder: 001b7d97-9425-43c3-a9a3-a36cb3d2a591
# File already exists
# Count: 2
#
# 🚀 Starting processing of: TCGA-D5-5539-01Z-00-DX1.9c46fe78-2adb-4f49-9141-cda135c2c90b.svs in folder: 00d69f69-3120-4b0c-8985-aab4edf9bc4b
# File already exists
# Count: 3
#
# 🚀 Starting processing of: TCGA-A6-2683-01Z-00-DX1.0dfc5d0a-68f4-45e1-a879-0428313c6dbc.svs in folder: 011da0ba-03eb-41cd-ae90-2dca944410e5
# ⚠️ Skipping TCGA-A6-2683-01Z-00-DX1.0dfc5d0a-68f4-45e1-a879-0428313c6dbc.svs: Not found or invalid in metadata.
# Count: 4
#
# 🚀 Starting processing of: TCGA-F4-6459-01Z-00-DX1.80a78213-1137-4521-9d60-ac64813dec4c.svs in folder: 01f2d311-0825-4c67-af09-cf1a5ae6b1af
# File already exists
# Count: 5
#
# 🚀 Starting processing of: TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs in folder: 021821c9-68f3-4be3-97ec-4ade5b4aaa60
# File already exists
# Count: 6
#
# 🚀 Starting processing of: TCGA-A6-6653-01Z-00-DX1.e130666d-2681-4382-9e7a-4a4d27cb77a4.svs in folder: 023ca8d1-d8ef-492e-b542-e5e16e1ded09
# File already exists
# Count: 7
#
# 🚀 Starting processing of: TCGA-DM-A1D8-01Z-00-DX1.2DD544F5-D72F-4840-B2D3-F361E032EA3B.svs in folder: 02a30d63-1da6-42d0-ab89-b4992ddcacec
# File already exists
# Count: 8
#
# 🚀 Starting processing of: TCGA-AG-3581-01Z-00-DX1.2d8ba8ba-0533-41e5-b0e0-0d49ef408302.svs in folder: 02e1301c-1ee8-4853-9925-d01a1e7f7c3c
# ⚠️ Skipping TCGA-AG-3581-01Z-00-DX1.2d8ba8ba-0533-41e5-b0e0-0d49ef408302.svs: Not found or invalid in metadata.
# Count: 9
#
# 🚀 Starting processing of: TCGA-A6-5657-01Z-00-DX1.d0cab3dd-8758-4a3e-8bb2-7cd9411dbeb6.svs in folder: 03d1d2c0-b00c-4b48-af63-70ca7300ed15
# File already exists
# Count: 10
#
# 🚀 Starting processing of: TCGA-CK-4950-01Z-00-DX1.03dcc4c2-2b63-45a2-8561-bf18193202b5.svs in folder: 03e74334-057d-47f1-9651-4a270ca1f943
# File already exists
# Count: 11
#
# 🚀 Starting processing of: TCGA-4T-AA8H-01Z-00-DX1.A46C759C-74A2-4724-B6B5-DECA0D16E029.svs in folder: 04d586ad-4f74-453f-a9c6-f8bd134ae11c
# ⚠️ Skipping TCGA-4T-AA8H-01Z-00-DX1.A46C759C-74A2-4724-B6B5-DECA0D16E029.svs: Not found or invalid in metadata.
# Count: 12
#
# 🚀 Starting processing of: TCGA-T9-A92H-01Z-00-DX1.9BA130C5-CAEF-4452-BB1F-61963B0DA3C5.svs in folder: 0595727b-58bb-45e8-8a54-ce1e8e9df83a
# File already exists
# Count: 13
#
# 🚀 Starting processing of: TCGA-CA-6718-01Z-00-DX1.9774472f-a29a-4b2b-8e50-ccbf9e5f9686.svs in folder: 05b07eb8-5db7-4755-8a0c-900059c0e3af
# File already exists
# Count: 14
#
# 🚀 Starting processing of: TCGA-CA-5796-01Z-00-DX1.88141789-4240-4ab7-8db1-e4cb7ee1ebda.svs in folder: 05d5bb0d-6a62-4967-92c0-f4e9bc53a0b4
# File already exists
# Count: 15
#
# 🚀 Starting processing of: TCGA-D5-6535-01Z-00-DX1.0d7485ff-cf98-4c86-8a61-c7364f41b8b0.svs in folder: 064f3779-aeb1-4be1-9b86-76edc95a5c28
# File already exists
# Count: 16
#
# 🚀 Starting processing of: TCGA-CM-5863-01Z-00-DX1.2dceed07-9373-4103-be16-533dac9f283b.svs in folder: 06a6a408-3198-4911-bdea-8e56cd0554a3
# File already exists
# Count: 17
#
# 🚀 Starting processing of: TCGA-AA-3814-01Z-00-DX1.15a569dc-30d6-4bef-908b-6183df4e9e01.svs in folder: 06c18d96-66e2-4f68-834c-3da4bc9878da
# File already exists
# Count: 18
#
# 🚀 Starting processing of: TCGA-AA-3664-01Z-00-DX1.bd07e7ef-0acb-43d8-a4f6-15b3442d2ed5.svs in folder: 08ef38c6-068b-420d-b629-d7778492c0a9
# File already exists
# Count: 19
#
# 🚀 Starting processing of: TCGA-EI-6513-01Z-00-DX1.9d978c83-0ec2-46cc-8be5-9721b6c7cbd3.svs in folder: 093250fd-a3d4-485f-943c-76c085f0cff4
# File already exists
# Count: 20
#
# 🚀 Starting processing of: TCGA-AD-A5EK-01Z-00-DX1.709B3557-3E24-4CAB-8CD6-604C9438BC12.svs in folder: 098102b9-668a-4743-b8b8-b0f1e1bd345c
# File already exists
# Count: 21
#
# 🚀 Starting processing of: TCGA-A6-6654-01Z-00-DX1.ed491b61-7c44-4275-879b-22f8007b5ff1.svs in folder: 09b18cbc-7c10-4b9f-af6b-4dd8c2e8218a
# File already exists
# Count: 22
#
# 🚀 Starting processing of: TCGA-A6-2674-01Z-00-DX1.d301f1f5-6f4a-49e6-9c93-f4e8b7f616b8.svs in folder: 0acc3fcf-1209-4824-8d25-e4d0c0f2ac1b
# ⚠️ Skipping TCGA-A6-2674-01Z-00-DX1.d301f1f5-6f4a-49e6-9c93-f4e8b7f616b8.svs: Not found or invalid in metadata.
# Count: 23
#
# 🚀 Starting processing of: TCGA-AH-6903-01Z-00-DX1.29f3feae-e757-4138-9f86-439fac247009.svs in folder: 0ae1ce57-7580-48de-9f8b-2eff2173b538
# File already exists
# Count: 24
#
# 🚀 Starting processing of: TCGA-A6-5662-01Z-00-DX1.82569684-1c31-4346-af9b-c296a020f624.svs in folder: 0b55ba87-0994-4679-9d1c-6cc3ddfd3078
# File already exists
# Count: 25
#
# 🚀 Starting processing of: TCGA-A6-A567-01Z-00-DX1.F941874E-9BF7-4E8B-908C-41A638D62275.svs in folder: 0b9fadfc-f3ba-4af2-899c-bf804369fd55
# File already exists
# Count: 26
#
# 🚀 Starting processing of: TCGA-AA-3941-01Z-00-DX1.7c445fb8-53ee-4813-9ca8-8f7c3cc0bdde.svs in folder: 0bd355d5-4062-42ba-88e4-30af0dd8f1e6
# ⚠️ Skipping TCGA-AA-3941-01Z-00-DX1.7c445fb8-53ee-4813-9ca8-8f7c3cc0bdde.svs: Not found or invalid in metadata.
# Count: 27
#
# 🚀 Starting processing of: TCGA-F4-6856-01Z-00-DX1.2872c7b5-b94d-4147-ad90-69f88668135a.svs in folder: 0bdf189f-bfe3-4587-8303-d1905a3822e4
# File already exists
# Count: 28
#
# 🚀 Starting processing of: TCGA-AU-3779-01Z-00-DX1.4134005A-8A79-46DC-8737-B3C8AAC2DFCA.svs in folder: 0c59c32a-ce9a-4557-be21-90d72ddc34b4
# File already exists
# Count: 29
#
# 🚀 Starting processing of: TCGA-CK-5912-01Z-00-DX1.23a955f3-a1ed-4cb3-8e49-cbb3f789f3f5.svs in folder: 0dc16a72-93b4-4c47-b58b-dec3979085b9
# File already exists
# Count: 30
#
# 🚀 Starting processing of: TCGA-DM-A285-01Z-00-DX1.219e2829-8ffd-4b51-adce-cfd48293191b.svs in folder: 0e5316aa-c726-46e3-881b-c2bf918c1231
# File already exists
# Count: 31
#
# 🚀 Starting processing of: TCGA-AA-3949-01Z-00-DX1.23748e80-0d7e-4238-8b29-f74cddae8596.svs in folder: 0e720a10-f234-41ae-b885-dc32e86778db
# File already exists
# Count: 32
#
# 🚀 Starting processing of: TCGA-AA-3524-01Z-00-DX1.b1aae264-87be-4514-8f9d-25660b39caa7.svs in folder: 0ecb2d7b-0a69-46ce-80d6-1be65cec3cc7
# ⚠️ Skipping TCGA-AA-3524-01Z-00-DX1.b1aae264-87be-4514-8f9d-25660b39caa7.svs: Not found or invalid in metadata.
# Count: 33
#
# 🚀 Starting processing of: TCGA-G4-6588-01Z-00-DX1.0747172e-f630-4b7c-9341-55078585ae00.svs in folder: 0eced714-3cec-43d5-a956-72f7ab15cb94
# File already exists
# Count: 34
#
# 🚀 Starting processing of: TCGA-AG-3732-01Z-00-DX1.5EC57511-2B19-4005-BCA0-333C387C66E6.svs in folder: 0f4229c7-5a59-41d4-aecf-50388c12336d
# ⚠️ Skipping TCGA-AG-3732-01Z-00-DX1.5EC57511-2B19-4005-BCA0-333C387C66E6.svs: Not found or invalid in metadata.
# Count: 35
#
# 🚀 Starting processing of: TCGA-AG-3999-01Z-00-DX1.d963afa8-565a-4da8-ab5c-7c7cadf30b0f.svs in folder: 0f526db0-c865-45a8-ba63-6cd558e61e63
# ⚠️ Skipping TCGA-AG-3999-01Z-00-DX1.d963afa8-565a-4da8-ab5c-7c7cadf30b0f.svs: Not found or invalid in metadata.
# Count: 36
#
# 🚀 Starting processing of: TCGA-EF-5830-01Z-00-DX1.618859B2-6B71-4BF8-9679-3C3EAC4BA2C5.svs in folder: 0f942b8b-1f54-49a9-9d47-fa732d79fafe
# File already exists
# Count: 37
#
# 🚀 Starting processing of: TCGA-A6-5665-01Z-00-DX1.3ad2c249-d138-4037-a59b-4747ce2b789a.svs in folder: 103810e8-c721-4242-b729-270097a23469
# File already exists
# Count: 38
#
# 🚀 Starting processing of: TCGA-AA-3531-01Z-00-DX1.19cdaa4b-5a53-4198-90da-5800827d90bf.svs in folder: 10b38301-6ac8-40a9-ae81-b2ecf64a5d3c
# ⚠️ Skipping TCGA-AA-3531-01Z-00-DX1.19cdaa4b-5a53-4198-90da-5800827d90bf.svs: Not found or invalid in metadata.
# Count: 39
#
# 🚀 Starting processing of: TCGA-A6-4105-01Z-00-DX1.228b02a5-04fa-4392-bf03-b297c19665c3.svs in folder: 10efa9de-0389-4ecf-8297-cce33b2dc6c9
# File already exists
# Count: 40
#
# 🚀 Starting processing of: TCGA-D5-6926-01Z-00-DX1.3830423a-3587-432b-9a6c-84f838e49fe6.svs in folder: 11489c71-5516-4ca3-8256-4c91ac223e20
# File already exists
# Count: 41
#
# 🚀 Starting processing of: TCGA-AA-3869-01Z-00-DX1.ef8b8cf0-5de5-4475-ac37-286d58604a0f.svs in folder: 115cba1c-9950-4067-a213-3f7963b51960
# ⚠️ Skipping TCGA-AA-3869-01Z-00-DX1.ef8b8cf0-5de5-4475-ac37-286d58604a0f.svs: Not found or invalid in metadata.
# Count: 42
#
# 🚀 Starting processing of: TCGA-AG-4001-01Z-00-DX1.1dbafe58-de6b-47a0-9b47-15c5f9401bef.svs in folder: 11dffd74-1be0-4539-98e5-9062024a7cd5
# File already exists
# Count: 43
#
# 🚀 Starting processing of: TCGA-G5-6233-01Z-00-DX1.86802633-c8f3-4d1e-85ab-f2ce2fe0a7ed.svs in folder: 120dbfa2-bc0b-4f49-ae54-026f8819ef1e
# ⚠️ Skipping TCGA-G5-6233-01Z-00-DX1.86802633-c8f3-4d1e-85ab-f2ce2fe0a7ed.svs: Not found or invalid in metadata.
# Count: 44
#
# 🚀 Starting processing of: TCGA-AA-A01T-01Z-00-DX1.0C795296-87D6-4B90-9363-CF5CD7A2924D.svs in folder: 128f36a1-0433-4533-87c3-743f13a586fe
# File already exists
# Count: 45
#
# 🚀 Starting processing of: TCGA-DC-4745-01Z-00-DX1.f5aa77b0-aa9b-4f0c-a007-5d507daed69a.svs in folder: 12c2ee6d-85cd-41ea-bd70-880adace3336
# File already exists
# Count: 46
#
# 🚀 Starting processing of: TCGA-A6-A56B-01Z-00-DX1.52FE9FA5-05F1-49EA-98BE-887CF7B3A52F.svs in folder: 13943a8e-e3d3-4db4-9000-bc3a16666b56
# File already exists
# Count: 47
#
# 🚀 Starting processing of: TCGA-AA-3986-01Z-00-DX1.db60e495-c0eb-416c-b65b-55ce62ed10b0.svs in folder: 13ea8b59-6628-4faa-8047-6628704c4636
# File already exists
# Count: 48
#
# 🚀 Starting processing of: TCGA-AG-4015-01Z-00-DX1.043fe5dc-2492-4cfa-bfc2-634fe2e341ab.svs in folder: 14551352-8f32-4910-8e80-4f06104de9a0
# File already exists
# Count: 49
#
# 🚀 Starting processing of: TCGA-EI-6511-01Z-00-DX1.91431e0b-91c6-4ab1-8ab6-e8967ff482ae.svs in folder: 152f8b1a-282c-4ae5-824c-10c700f0d5c2
# File already exists
# Count: 50
#
# 🚀 Starting processing of: TCGA-AF-3400-01Z-00-DX1.b5c266c7-b465-4478-8058-cdf3f35dff38.svs in folder: 15390cdf-59a5-43c8-89d1-08028388b850
# ⚠️ Skipping TCGA-AF-3400-01Z-00-DX1.b5c266c7-b465-4478-8058-cdf3f35dff38.svs: Not found or invalid in metadata.
# Count: 51
#
# 🚀 Starting processing of: TCGA-CA-6717-01Z-00-DX1.08da75b7-a08f-46b3-a8c0-24f601ec4558.svs in folder: 158a9449-075b-4fba-a146-9d426d207b1e
# File already exists
# Count: 52
#
# 🚀 Starting processing of: TCGA-AG-3592-01Z-00-DX1.61880D0C-B777-482B-9543-FCA685731B9B.svs in folder: 15a3d699-1c64-4711-969b-dbffda0a5f9f
# ⚠️ Skipping TCGA-AG-3592-01Z-00-DX1.61880D0C-B777-482B-9543-FCA685731B9B.svs: Not found or invalid in metadata.
# Count: 53
#
# 🚀 Starting processing of: TCGA-AZ-6599-01Z-00-DX1.9d6aae3d-6934-4e96-8699-db41e1194f29.svs in folder: 15d3e243-669f-40e8-8c9c-8d039929172c
# File already exists
# Count: 54
#
# 🚀 Starting processing of: TCGA-CK-4947-01Z-00-DX1.b257d5fd-b97b-4987-b088-77f044ca7fe2.svs in folder: 16a5bceb-dba9-4c63-92bf-a63c5901d0b6
# File already exists
# Count: 55
#
# 🚀 Starting processing of: TCGA-A6-6651-01Z-00-DX1.09ad2d69-d71d-4fa2-9504-80557a053db4.svs in folder: 16dd80c6-0980-48a3-af88-4bf03cf71fce
# File already exists
# Count: 56
#
# 🚀 Starting processing of: TCGA-AA-3977-01Z-00-DX1.08ffa326-08fd-4215-9bf7-81fcf33b4f5a.svs in folder: 176f2cac-68c9-42fd-bc5f-7d096ecdd069
# ⚠️ Skipping TCGA-AA-3977-01Z-00-DX1.08ffa326-08fd-4215-9bf7-81fcf33b4f5a.svs: Not found or invalid in metadata.
# Count: 57
#
# 🚀 Starting processing of: TCGA-AA-3837-01Z-00-DX1.5692e5c0-6dc2-45be-a5f5-00a907c5c824.svs in folder: 17cfcc8c-49a4-48ce-a5e1-4a3c582ce198
# File already exists
# Count: 58
#
# 🚀 Starting processing of: TCGA-D5-6540-01Z-00-DX1.4ca9e502-959b-4fa8-a748-5fd0878e5c3f.svs in folder: 17eb2473-7018-474e-ad62-e95be30edcb1
# File already exists
# Count: 59
#
# 🚀 Starting processing of: TCGA-CL-5918-01Z-00-DX1.c3bac47e-2737-419a-ab97-5d3f923f8986.svs in folder: 18b6f428-76dc-41e9-b1de-dc3a4afd4f7b
# File already exists
# Count: 60
#
# 🚀 Starting processing of: TCGA-CM-4744-01Z-00-DX1.527ead53-bd55-4321-adea-079bf5e2e8a5.svs in folder: 1b2d9c2e-5f7e-44a7-bef5-9c6ffda97429
# File already exists
# Count: 61
#
# 🚀 Starting processing of: TCGA-F4-6703-01Z-00-DX1.28225f5d-d880-4605-831f-f22ec0272cde.svs in folder: 1badcce0-68c4-44b0-9b4e-acbb94c3fe3b
# File already exists
# Count: 62
#
# 🚀 Starting processing of: TCGA-AA-3660-01Z-00-DX1.CCD0F50D-9991-4CC2-AC77-AD1F78D8CFEB.svs in folder: 1ca35a8e-3911-4247-a906-832f3223e192
# ⚠️ Skipping TCGA-AA-3660-01Z-00-DX1.CCD0F50D-9991-4CC2-AC77-AD1F78D8CFEB.svs: Not found or invalid in metadata.
# Count: 63
#
# 🚀 Starting processing of: TCGA-NH-A6GB-01Z-00-DX1.AD90C375-54ED-4EE4-A537-59A2E3FE4BCD.svs in folder: 1ce88052-f889-4630-871d-09de5c5ad369
# File already exists
# Count: 64
#
# 🚀 Starting processing of: TCGA-G4-6298-01Z-00-DX1.83055d52-71f7-46ec-be53-11d86b19b4cf.svs in folder: 1e1d8d98-9965-4c8d-92dd-c88cfc6cce2c
# File already exists
# Count: 65
#
# 🚀 Starting processing of: TCGA-DT-5265-01Z-00-DX1.563f09af-8bbe-45cd-9c6d-85a96255e67f.svs in folder: 1e6df8d7-4997-4765-921c-a758f53da599
# File already exists
# Count: 66
#
# 🚀 Starting processing of: TCGA-AH-6549-01Z-00-DX1.38ea40f7-4ebf-49cc-801b-4dcf3c50cc5e.svs in folder: 1f07b827-255a-4d32-9eea-f2daff7bd937
# ⚠️ Skipping TCGA-AH-6549-01Z-00-DX1.38ea40f7-4ebf-49cc-801b-4dcf3c50cc5e.svs: Not found or invalid in metadata.
# Count: 67
#
# 🚀 Starting processing of: TCGA-D5-5540-01Z-00-DX1.4e4c69ca-f736-4db3-a401-c4f814d975dd.svs in folder: 1f590735-088d-4821-85d1-599b77725221
# File already exists
# Count: 68
#
# 🚀 Starting processing of: TCGA-AG-A00Y-01Z-00-DX1.E98EC504-95CA-4C34-924C-D40ADF323617.svs in folder: 1f8644d6-fa9a-4af5-8fe4-486f3e93eaa1
# ⚠️ Skipping TCGA-AG-A00Y-01Z-00-DX1.E98EC504-95CA-4C34-924C-D40ADF323617.svs: Not found or invalid in metadata.
# Count: 69
#
# 🚀 Starting processing of: TCGA-G4-6307-01Z-00-DX1.fff548a0-8bc8-428e-a4ce-3a5d0b3f060b.svs in folder: 2078ca83-55e7-4f53-83d6-82e1682cb493
# File already exists
# Count: 70
#
# 🚀 Starting processing of: TCGA-AA-3867-01Z-00-DX1.dbc11b4b-732c-4b0a-aaef-ba94b0218fe6.svs in folder: 20a11849-e57a-47ad-854c-757e17cc277b
# File already exists
# Count: 71
#
# 🚀 Starting processing of: TCGA-AZ-6606-01Z-00-DX1.aa79b3d8-8ff1-4171-96dc-94bc7d073d93.svs in folder: 20c10ff9-8505-451d-adb0-aacfe649ad79
# File already exists
# Count: 72
#
# 🚀 Starting processing of: TCGA-AA-3560-01Z-00-DX1.7ca786bd-777e-4b33-8778-fc5e2b061ff1.svs in folder: 20c54d6e-a4cb-4503-aafb-a70b8c342b9a
# ⚠️ Skipping TCGA-AA-3560-01Z-00-DX1.7ca786bd-777e-4b33-8778-fc5e2b061ff1.svs: Not found or invalid in metadata.
# Count: 73
#
# 🚀 Starting processing of: TCGA-CM-5861-01Z-00-DX1.b900abc0-ecca-48e1-98ba-fbc99a6dae3e.svs in folder: 2100a74b-8905-4848-b51a-5d7764871620
# File already exists
# Count: 74
#
# 🚀 Starting processing of: TCGA-CM-5868-01Z-00-DX1.70f2e193-248d-4bf9-a875-49c314223f70.svs in folder: 21471300-f78e-4174-bdc9-7a4076c5f1b7
# File already exists
# Count: 75
#
# 🚀 Starting processing of: TCGA-AA-A03J-01Z-00-DX1.4E57E86E-ADEE-4837-9F91-E9CA141F7ACC.svs in folder: 219576f3-3c71-44f8-a23d-addde6ef33dc
# File already exists
# Count: 76
#
# 🚀 Starting processing of: TCGA-NH-A50V-01Z-00-DX1.408BA0A6-E569-4464-A8CB-D6553A4DF9E0.svs in folder: 21b6d67b-524b-4172-a741-32790e6d9742
# File already exists
# Count: 77
#
# 🚀 Starting processing of: TCGA-AZ-6608-01Z-00-DX1.40d9f93f-f7d8-4138-9af1-bb579c53194b.svs in folder: 2225f73e-f46f-4927-b23a-5a647f9fff6a
# ⚠️ Skipping TCGA-AZ-6608-01Z-00-DX1.40d9f93f-f7d8-4138-9af1-bb579c53194b.svs: Not found or invalid in metadata.
# Count: 78
#
# 🚀 Starting processing of: TCGA-A6-A5ZU-01Z-00-DX2.221EC8DE-4029-4ED2-8D84-95647BD39E03.svs in folder: 223b9587-088a-4fbf-a750-9ce0d51a016c
# ⚠️ Skipping TCGA-A6-A5ZU-01Z-00-DX2.221EC8DE-4029-4ED2-8D84-95647BD39E03.svs: Not found or invalid in metadata.
# Count: 79
#
# 🚀 Starting processing of: TCGA-AA-3561-01Z-00-DX1.1b5a2925-53f9-470f-a62c-cc2e5d5abb58.svs in folder: 227fecea-0d2a-4eaf-b32a-1129887d6926
# ⚠️ Skipping TCGA-AA-3561-01Z-00-DX1.1b5a2925-53f9-470f-a62c-cc2e5d5abb58.svs: Not found or invalid in metadata.
# Count: 80
#
# 🚀 Starting processing of: TCGA-AA-A01P-01Z-00-DX1.D7AAA4F0-C956-4346-8948-DADACDFB3B69.svs in folder: 22c257cf-df9e-441a-a21c-d78b2b528087
# File already exists
# Count: 81
#
# 🚀 Starting processing of: TCGA-AZ-4681-01Z-00-DX1.e468c1a1-e251-4521-82fe-526c9c5f8190.svs in folder: 23055574-65ae-4a76-9968-7dfcb5336cf7
# File already exists
# Count: 82
#
# 🚀 Starting processing of: TCGA-AG-A014-01Z-00-DX1.B1C4F8FA-B049-413B-9759-77FEC8B433C1.svs in folder: 23132d97-3391-4aa0-b7c7-4ad913ae5d00
# ⚠️ Skipping TCGA-AG-A014-01Z-00-DX1.B1C4F8FA-B049-413B-9759-77FEC8B433C1.svs: Not found or invalid in metadata.
# Count: 83
#
# 🚀 Starting processing of: TCGA-F5-6702-01Z-00-DX1.6f9c3c37-a762-4847-a3c6-44ea50b34eec.svs in folder: 23bb4100-e6b9-4199-8ec5-cf8fec186373
# File already exists
# Count: 84
#
# 🚀 Starting processing of: TCGA-AG-A02G-01Z-00-DX1.E9848C07-0DFC-48E7-AA9F-9BF783676468.svs in folder: 23d592d6-be43-4de4-bc95-2ef02ae06bcb
# ⚠️ Skipping TCGA-AG-A02G-01Z-00-DX1.E9848C07-0DFC-48E7-AA9F-9BF783676468.svs: Not found or invalid in metadata.
# Count: 85
#
# 🚀 Starting processing of: TCGA-AF-2690-01Z-00-DX1.22cb3fa6-519d-449f-b486-1f35c9089164.svs in folder: 242947d0-a9ff-49d7-888e-8195c86186fe
# File already exists
# Count: 86
#
# 🚀 Starting processing of: TCGA-AZ-5407-01Z-00-DX1.5218a617-9817-44f4-8f00-8e9e3d04bd70.svs in folder: 2463c8f1-f8e8-4fab-881f-8875c2ec663b
# File already exists
# Count: 87
#
# 🚀 Starting processing of: TCGA-AA-A02E-01Z-00-DX1.04D47621-9DCF-437C-A4D6-44D17579FE6D.svs in folder: 25d00401-5200-417f-8955-ddba65eebdb7
# File already exists
# Count: 88
#
# 🚀 Starting processing of: TCGA-CM-6677-01Z-00-DX1.e3428c0a-a194-4e38-b105-8244701fcc71.svs in folder: 25e4ffbf-32ed-407c-ac26-fcd5aa122e52
# File already exists
# Count: 89
#
# 🚀 Starting processing of: TCGA-AA-A01K-01Z-00-DX1.2E147232-BC3C-48CC-B75E-43E6AA4A0BF8.svs in folder: 262569d9-5fb0-4e7b-923c-a8285ced66b0
# ⚠️ Skipping TCGA-AA-A01K-01Z-00-DX1.2E147232-BC3C-48CC-B75E-43E6AA4A0BF8.svs: Not found or invalid in metadata.
# Count: 90
#
# 🚀 Starting processing of: TCGA-3L-AA1B-01Z-00-DX2.17CE3683-F4B1-4978-A281-8F620C4D77B4.svs in folder: 263abaf6-c5a1-4215-8dd5-a8b2a7bfd745
# File already exists
# Count: 91
#
# 🚀 Starting processing of: TCGA-CM-5862-01Z-00-DX1.df57752c-5937-40f2-a48f-37a147a82139.svs in folder: 2678c27a-d474-4960-bb99-b4135a8e0353
# File already exists
# Count: 92
#
# 🚀 Starting processing of: TCGA-5M-AAT4-01Z-00-DX1.725C46CA-9354-43AC-AA81-3E5A66354D6B.svs in folder: 2680fe2f-eef9-404e-a6a3-cdec178460a8
# File already exists
# Count: 93
#
# 🚀 Starting processing of: TCGA-AZ-4614-01Z-00-DX1.c1488dfe-528f-4dd4-b5f8-da81fbb4ec0b.svs in folder: 2704d972-b63d-4db8-b1e4-56ba9721d6a6
# File already exists
# Count: 94
#
# 🚀 Starting processing of: TCGA-AA-3672-01Z-00-DX1.6cc142eb-e77f-4c09-a6ac-e85470221812.svs in folder: 27ac8b0a-9daa-4fe6-8bd7-067f18f4a389
# ⚠️ Skipping TCGA-AA-3672-01Z-00-DX1.6cc142eb-e77f-4c09-a6ac-e85470221812.svs: Not found or invalid in metadata.
# Count: 95
#
# 🚀 Starting processing of: TCGA-DM-A28F-01Z-00-DX1.3ebf56a0-8f55-4681-bc7f-1e20d802a966.svs in folder: 28515fea-02da-4b19-9554-6cd9cc55a3d2
# File already exists
# Count: 96
#
# 🚀 Starting processing of: TCGA-EI-6509-01Z-00-DX1.3676fab0-3e79-4b57-b592-c1af5aee40f6.svs in folder: 28647e05-e6b9-431c-94bf-afd7d79425f7
# File already exists
# Count: 97
#
# 🚀 Starting processing of: TCGA-AA-3979-01Z-00-DX1.e63b4db2-dc9b-4afb-a288-89a905beacd0.svs in folder: 28fa386a-97e2-4144-8ab0-29ebe01a7774
# File already exists
# Count: 98
#
# 🚀 Starting processing of: TCGA-AA-3518-01Z-00-DX1.5aad7b19-2900-4f1c-9312-f8d8c4725449.svs in folder: 29b005db-4568-4685-8a33-7b0c331f6ae3
# ⚠️ Skipping TCGA-AA-3518-01Z-00-DX1.5aad7b19-2900-4f1c-9312-f8d8c4725449.svs: Not found or invalid in metadata.
# Count: 99
#
# 🚀 Starting processing of: TCGA-CK-5915-01Z-00-DX1.04650539-005e-4221-90d6-49706b1d7244.svs in folder: 2adbf842-77f4-4fa9-a440-9ef5c53de2fd
# File already exists
# Count: 100
#
# 🚀 Starting processing of: TCGA-D5-6932-01Z-00-DX1.d18111de-f0f5-4637-8534-a2b4396cbb41.svs in folder: 2b02baad-7143-4fea-9f28-ff2d4efc4044
# File already exists
# Count: 101
#
# 🚀 Starting processing of: TCGA-AA-3534-01Z-00-DX1.a49495e0-93b2-41fa-9229-6375533578b5.svs in folder: 2b2ba75b-ae19-49d4-b14d-1f49a0fa9613
# ⚠️ Skipping TCGA-AA-3534-01Z-00-DX1.a49495e0-93b2-41fa-9229-6375533578b5.svs: Not found or invalid in metadata.
# Count: 102
#
# 🚀 Starting processing of: TCGA-AD-6899-01Z-00-DX1.646f5e1a-212f-4b15-8689-8b55f7ba8c47.svs in folder: 2bbf3cea-c7cb-4410-9151-7281132bdae5
# ⚠️ Skipping TCGA-AD-6899-01Z-00-DX1.646f5e1a-212f-4b15-8689-8b55f7ba8c47.svs: Not found or invalid in metadata.
# Count: 103
#
# 🚀 Starting processing of: TCGA-AF-2687-01Z-00-DX1.bbcd88f6-11d5-4b57-9693-693124b2b7e7.svs in folder: 2c0da95f-22b6-42c4-ad5d-1e509735b7f7
# File already exists
# Count: 104
#
# 🚀 Starting processing of: TCGA-G4-6304-01Z-00-DX1.cf678a4f-5448-4d6a-a36f-cd1aec4d48a7.svs in folder: 2c275682-06bf-4321-9135-890af2807717
# File already exists
# Count: 105
#
# 🚀 Starting processing of: TCGA-G4-6314-01Z-00-DX1.bea21980-9584-4382-9de3-4c5114edb10d.svs in folder: 2c2dc5d7-b7ff-4043-811d-3b24c1ae4184
# ⚠️ Skipping TCGA-G4-6314-01Z-00-DX1.bea21980-9584-4382-9de3-4c5114edb10d.svs: Not found or invalid in metadata.
# Count: 106
#
# 🚀 Starting processing of: TCGA-CA-5256-01Z-00-DX1.67cc2ca1-40df-4e76-be88-dfd93e20e017.svs in folder: 2c8b6894-a7b0-4a08-94ea-26bedbb0dffc
# File already exists
# Count: 107
#
# 🚀 Starting processing of: TCGA-AG-3725-01Z-00-DX1.86CF8220-F410-49E4-A840-E42AE8C5D8B2.svs in folder: 2cd68fa7-8178-478f-bd58-aeaa0fe42380
# ⚠️ Skipping TCGA-AG-3725-01Z-00-DX1.86CF8220-F410-49E4-A840-E42AE8C5D8B2.svs: Not found or invalid in metadata.
# Count: 108
#
# 🚀 Starting processing of: TCGA-G4-6294-01Z-00-DX1.29a1716d-8875-49f0-8a83-f416221623b3.svs in folder: 2d08a6f8-70b3-4c3e-aa8f-1bc325f37282
# File already exists
# Count: 109
#
# 🚀 Starting processing of: TCGA-A6-2682-01Z-00-DX1.be71dca0-b9b7-40be-a6c6-9d053c7886a6.svs in folder: 2d3b690e-06a8-43ad-9235-dc5eef98dd19
# ⚠️ Skipping TCGA-A6-2682-01Z-00-DX1.be71dca0-b9b7-40be-a6c6-9d053c7886a6.svs: Not found or invalid in metadata.
# Count: 110
#
# 🚀 Starting processing of: TCGA-AF-3914-01Z-00-DX2.493568CE-EAC1-400D-87E1-01A22F689D21.svs in folder: 2d58d2f2-fdfb-4c94-b996-79a0f270f646
# ⚠️ Skipping TCGA-AF-3914-01Z-00-DX2.493568CE-EAC1-400D-87E1-01A22F689D21.svs: Not found or invalid in metadata.
# Count: 111
#
# 🚀 Starting processing of: TCGA-AG-3887-01Z-00-DX1.4973b987-ee11-4a5b-a2ba-d9910b363486.svs in folder: 2d8a4d58-2681-4fc9-9181-0a68bc86fdbc
# File already exists
# Count: 112
#
# 🚀 Starting processing of: TCGA-AG-3883-01Z-00-DX1.2a21ffb1-8a60-4424-b74d-4c85b7894953.svs in folder: 2d8f32f9-bb04-46cd-8d63-91b591e9b8b3
# File already exists
# Count: 113
#
# 🚀 Starting processing of: TCGA-CK-6747-01Z-00-DX1.7824596c-84db-4bee-b149-cd8f617c285f.svs in folder: 2d961af6-9f08-4db7-92b2-52b2380cd022
# File already exists
# Count: 114
#
# 🚀 Starting processing of: TCGA-CM-5341-01Z-00-DX1.af4f75ff-3971-4639-8ef4-918ef4b29df0.svs in folder: 2db970a8-1f49-4b6e-b8be-639cef516156
# File already exists
# Count: 115
#
# 🚀 Starting processing of: TCGA-AG-A01W-01Z-00-DX1.3300D796-28C2-40E9-81BF-1793069C0FE7.svs in folder: 2dcf942e-f9cf-41e3-9465-c2bf23478a2a
# File already exists
# Count: 116
#
# 🚀 Starting processing of: TCGA-A6-2675-01Z-00-DX1.d37847d6-c17f-44b9-b90a-84cd1946c8ab.svs in folder: 2e1217f8-442e-431e-9036-1e159627a9ae
# ⚠️ Skipping TCGA-A6-2675-01Z-00-DX1.d37847d6-c17f-44b9-b90a-84cd1946c8ab.svs: Not found or invalid in metadata.
# Count: 117
#
# 🚀 Starting processing of: TCGA-AA-A00Z-01Z-00-DX1.47847702-E46E-40AA-9BA6-2ED1912D1E73.svs in folder: 2e23c9a5-0e47-4b5a-9359-b73ed2dd1916
# ⚠️ Skipping TCGA-AA-A00Z-01Z-00-DX1.47847702-E46E-40AA-9BA6-2ED1912D1E73.svs: Not found or invalid in metadata.
# Count: 118
#
# 🚀 Starting processing of: TCGA-AZ-6603-01Z-00-DX1.e39d6a8c-a738-4d63-b094-11be49fac828.svs in folder: 2e5f3ab3-6945-4600-8720-122c77dd28e4
# File already exists
# Count: 119
#
# 🚀 Starting processing of: TCGA-CM-4747-01Z-00-DX1.e0fac451-1322-464e-b718-174e9db33f39.svs in folder: 2efd0746-94de-4e08-b7f9-e9babfeb84c3
# File already exists
# Count: 120
#
# 🚀 Starting processing of: TCGA-AF-2693-01Z-00-DX1.620a9998-65df-4024-b719-f2384b4e7d36.svs in folder: 2f21d4ce-cc8c-4ccb-b91e-3780cce55249
# File already exists
# Count: 121
#
# 🚀 Starting processing of: TCGA-AF-2689-01Z-00-DX1.38242a22-4fcd-471f-a81c-56a5fe6f9a3a.svs in folder: 2fac124a-8ad4-48b2-81b8-ad7c2f80d122
# ⚠️ Skipping TCGA-AF-2689-01Z-00-DX1.38242a22-4fcd-471f-a81c-56a5fe6f9a3a.svs: Not found or invalid in metadata.
# Count: 122
#
# 🚀 Starting processing of: TCGA-CK-6746-01Z-00-DX1.0aae8eec-1e82-494b-8779-d79fea8bec0c.svs in folder: 2fcfc546-8fa2-4f4f-92e1-12b4f6434a51
# File already exists
# Count: 123
#
# 🚀 Starting processing of: TCGA-AA-3538-01Z-00-DX1.60d0b039-25d6-4b71-a36f-5b2764a983ef.svs in folder: 2fd860a1-534f-49f7-8169-ece8748480ac
# ⚠️ Skipping TCGA-AA-3538-01Z-00-DX1.60d0b039-25d6-4b71-a36f-5b2764a983ef.svs: Not found or invalid in metadata.
# Count: 124
#
# 🚀 Starting processing of: TCGA-A6-5659-01Z-00-DX1.c671806f-013e-4d99-9841-cda5bd43eff1.svs in folder: 301a0478-49d9-4adf-b060-baf2b8cd8e51
# ⚠️ Skipping TCGA-A6-5659-01Z-00-DX1.c671806f-013e-4d99-9841-cda5bd43eff1.svs: Not found or invalid in metadata.
# Count: 125
#
# 🚀 Starting processing of: TCGA-G4-6625-01Z-00-DX1.0fa26667-2581-4f96-a891-d78dbc3299b4.svs in folder: 3042cadb-953f-4294-8b34-4a43d8b6e984
# ⚠️ Skipping TCGA-G4-6625-01Z-00-DX1.0fa26667-2581-4f96-a891-d78dbc3299b4.svs: Not found or invalid in metadata.
# Count: 126
#
# 🚀 Starting processing of: TCGA-AA-3522-01Z-00-DX1.bd54ca55-9036-4167-b8b9-14f4209b7e4d.svs in folder: 3058f5a6-b21a-4424-bd13-58fed2f4f959
# ⚠️ Skipping TCGA-AA-3522-01Z-00-DX1.bd54ca55-9036-4167-b8b9-14f4209b7e4d.svs: Not found or invalid in metadata.
# Count: 127
#
# 🚀 Starting processing of: TCGA-A6-6138-01Z-00-DX1.11a4fad6-dfa3-4236-b714-bf1023b54622.svs in folder: 30ea4f08-2d34-466d-86b8-eb89ad03fe1d
# File already exists
# Count: 128
#
# 🚀 Starting processing of: TCGA-A6-5661-01Z-00-DX1.bad2d858-11b4-4b9c-a720-daaae592cf48.svs in folder: 31565365-1404-46ff-b4f6-a5c5294c9ba6
# File already exists
# Count: 129
#
# 🚀 Starting processing of: TCGA-CM-5349-01Z-00-DX1.d893eb9a-0321-4052-acfc-8c9a6e463921.svs in folder: 32268fd4-3c70-4906-97ac-c480f76fd00c
# File already exists
# Count: 130
#
# 🚀 Starting processing of: TCGA-D5-6931-01Z-00-DX1.c1d00654-b5ff-4485-90a6-97ae9e7bd7fa.svs in folder: 32409f33-aef7-4e0c-bf57-efac8614835c
# File already exists
# Count: 131
#
# 🚀 Starting processing of: TCGA-AA-3967-01Z-00-DX1.b80c87c9-00f4-44f6-bc59-19d2b94942ac.svs in folder: 325ffce4-1a0e-4bcc-bfc3-1a9959c26aee
# ⚠️ Skipping TCGA-AA-3967-01Z-00-DX1.b80c87c9-00f4-44f6-bc59-19d2b94942ac.svs: Not found or invalid in metadata.
# Count: 132
#
# 🚀 Starting processing of: TCGA-AH-6547-01Z-00-DX1.73040c3e-8219-4d21-88f2-613218d32297.svs in folder: 32abfee5-daea-4816-8c24-122dbf593aff
# File already exists
# Count: 133
#
# 🚀 Starting processing of: TCGA-AG-3611-01Z-00-DX1.c22e8af9-4211-46b4-b2aa-40b414025ae1.svs in folder: 333bacf6-bc83-4904-a791-345c244b7d7d
# ⚠️ Skipping TCGA-AG-3611-01Z-00-DX1.c22e8af9-4211-46b4-b2aa-40b414025ae1.svs: Not found or invalid in metadata.
# Count: 134
#
# 🚀 Starting processing of: TCGA-AA-3695-01Z-00-DX1.be93a101-7b57-4140-bd82-86c65e65ca27.svs in folder: 337025b3-97a6-4913-a4d2-3494f810884d
# ⚠️ Skipping TCGA-AA-3695-01Z-00-DX1.be93a101-7b57-4140-bd82-86c65e65ca27.svs: Not found or invalid in metadata.
# Count: 135
#
# 🚀 Starting processing of: TCGA-AA-3845-01Z-00-DX1.20682536-a009-4184-a40b-cb889f37ad32.svs in folder: 33a4ddef-d89c-4a9d-822d-33d3cf9527e4
# File already exists
# Count: 136
#
# 🚀 Starting processing of: TCGA-EI-6883-01Z-00-DX1.cbb30a39-9428-45f0-9178-40616322b073.svs in folder: 348b84c7-0d10-42e0-99d2-3ad23cfa25d9
# File already exists
# Count: 137
#
# 🚀 Starting processing of: TCGA-DC-6683-01Z-00-DX1.e1324f2d-db88-4416-adff-fffd9b361326.svs in folder: 34d74685-715e-40d8-a472-6eccef0b4a0f
# File already exists
# Count: 138
#
# 🚀 Starting processing of: TCGA-AA-3489-01Z-00-DX1.AE299B70-B14C-4FFE-B1F9-38B2EB267FA9.svs in folder: 35c1e23c-8adb-4a7f-865f-be1d6e10b3ef
# ⚠️ Skipping TCGA-AA-3489-01Z-00-DX1.AE299B70-B14C-4FFE-B1F9-38B2EB267FA9.svs: Not found or invalid in metadata.
# Count: 139
#
# 🚀 Starting processing of: TCGA-AA-3815-01Z-00-DX1.d6823390-73c1-431f-b480-0954f4df8224.svs in folder: 35edf06a-803c-4aef-bdb7-5965b86f69e9
# ⚠️ Skipping TCGA-AA-3815-01Z-00-DX1.d6823390-73c1-431f-b480-0954f4df8224.svs: Not found or invalid in metadata.
# Count: 140
#
# 🚀 Starting processing of: TCGA-AF-3914-01Z-00-DX1.d7bb7792-df51-498b-9d16-fc26e219249f.svs in folder: 36130f7e-c4bc-44e3-bc3b-44649955f546
# ⚠️ Skipping TCGA-AF-3914-01Z-00-DX1.d7bb7792-df51-498b-9d16-fc26e219249f.svs: Not found or invalid in metadata.
# Count: 141
#
# 🚀 Starting processing of: TCGA-A6-6648-01Z-00-DX1.88b9a490-0bed-43f3-bd74-1bf2810f6884.svs in folder: 363a0302-d11f-423a-adc6-e324dd65312b
# File already exists
# Count: 142
#
# 🚀 Starting processing of: TCGA-DC-6155-01Z-00-DX1.1a582653-3865-42d5-bf6c-2a05126e90ef.svs in folder: 3704c895-6d6e-4277-88f4-b4b4727e8374
# File already exists
# Count: 143
#
# 🚀 Starting processing of: TCGA-AG-4007-01Z-00-DX1.1344292e-78ad-4db8-b03b-e7ceb0c7027b.svs in folder: 371567a2-b1a4-4f5b-845b-4a07ffbf229d
# ⚠️ Skipping TCGA-AG-4007-01Z-00-DX1.1344292e-78ad-4db8-b03b-e7ceb0c7027b.svs: Not found or invalid in metadata.
# Count: 144
#
# 🚀 Starting processing of: TCGA-D5-6929-01Z-00-DX1.5e555bba-87b2-440c-b6d4-e6fec3f7bf3a.svs in folder: 372f70b7-4525-4b76-8f0d-33f3e0a190fe
# File already exists
# Count: 145
#
# 🚀 Starting processing of: TCGA-DY-A1DG-01Z-00-DX1.14B8412B-2A42-4340-BE32-299693AADAF6.svs in folder: 376bdbdb-ab7c-4a8b-b61a-7ed683f83758
# File already exists
# Count: 146
#
# 🚀 Starting processing of: TCGA-AA-3955-01Z-00-DX1.e0eea910-db79-4797-b9db-bb8bfe35306d.svs in folder: 37d511f7-036f-4750-b40e-8ef00a8ecfde
# ⚠️ Skipping TCGA-AA-3955-01Z-00-DX1.e0eea910-db79-4797-b9db-bb8bfe35306d.svs: Not found or invalid in metadata.
# Count: 147
#
# 🚀 Starting processing of: TCGA-AF-A56K-01Z-00-DX1.5870355A-679E-4E4C-8A00-B13C6F2A3FF2.svs in folder: 38563b81-491b-43de-8898-cef2d1d2a3cc
# File already exists
# Count: 148
#
# 🚀 Starting processing of: TCGA-AA-3696-01Z-00-DX1.947f2c09-dfe9-4fdb-bf1a-9bf46d67f617.svs in folder: 38c8505b-bff5-43ea-8a8d-0911a84469e4
# File already exists
# Count: 149
#
# 🚀 Starting processing of: TCGA-AA-A01V-01Z-00-DX1.1AC200C2-F577-421D-B91F-F0A7251C3D90.svs in folder: 38d409ab-73c7-4c38-91bc-e86ee83a404c
# File already exists
# Count: 150
#
# 🚀 Starting processing of: TCGA-AA-3966-01Z-00-DX1.7bc0c76e-f2d9-4abd-b63c-dad01aa4b1f7.svs in folder: 3918b8a1-e2d2-4ecc-97ea-a8ad81474088
# File already exists
# Count: 151
#
# 🚀 Starting processing of: TCGA-AA-A00A-01Z-00-DX1.B51DF257-6110-404C-9B20-A3C3453788F6.svs in folder: 395f7bb8-037f-4126-98a9-2f48442d0606
# ⚠️ Skipping TCGA-AA-A00A-01Z-00-DX1.B51DF257-6110-404C-9B20-A3C3453788F6.svs: Not found or invalid in metadata.
# Count: 152
#
# 🚀 Starting processing of: TCGA-AA-3712-01Z-00-DX1.00E0ACE2-8CC5-4063-9C65-3CDD7F21B189.svs in folder: 3962ba26-19f7-46be-af73-e39b37a51c64
# ⚠️ Skipping TCGA-AA-3712-01Z-00-DX1.00E0ACE2-8CC5-4063-9C65-3CDD7F21B189.svs: Not found or invalid in metadata.
# Count: 153
#
# 🚀 Starting processing of: TCGA-A6-2672-01Z-00-DX1.e2a845c8-6d77-4120-9f43-abec84a66c1c.svs in folder: 39a4f424-780f-44fe-8d60-1e2ffe8ce6c6
# ⚠️ Skipping TCGA-A6-2672-01Z-00-DX1.e2a845c8-6d77-4120-9f43-abec84a66c1c.svs: Not found or invalid in metadata.
# Count: 154
#
# 🚀 Starting processing of: TCGA-AA-A02K-01Z-00-DX1.732DD8F9-A21A-4E97-A779-3400A6C3D19D.svs in folder: 39c5d9fb-92de-4cec-b690-92e27924f759
# ⚠️ Skipping TCGA-AA-A02K-01Z-00-DX1.732DD8F9-A21A-4E97-A779-3400A6C3D19D.svs: Not found or invalid in metadata.
# Count: 155
#
# 🚀 Starting processing of: TCGA-CM-6167-01Z-00-DX1.7adf00e3-6768-46bb-814c-b2f04c472cc8.svs in folder: 3a278a6f-e7d3-4507-903f-50a0ea8aa113
# File already exists
# Count: 156
#
# 🚀 Starting processing of: TCGA-AA-3509-01Z-00-DX1.EAE46823-3132-486F-8C2A-C0F548A08335.svs in folder: 3ac10c45-4096-4839-982d-3019e77587db
# ⚠️ Skipping TCGA-AA-3509-01Z-00-DX1.EAE46823-3132-486F-8C2A-C0F548A08335.svs: Not found or invalid in metadata.
# Count: 157
#
# 🚀 Starting processing of: TCGA-A6-6650-01Z-00-DX1.92f39e59-8784-4dfd-a06f-804bebcdfb26.svs in folder: 3b20cf7f-b717-45d9-be7a-657df3c6f579
# ⚠️ Skipping TCGA-A6-6650-01Z-00-DX1.92f39e59-8784-4dfd-a06f-804bebcdfb26.svs: Not found or invalid in metadata.
# Count: 158
#
# 🚀 Starting processing of: TCGA-AA-3530-01Z-00-DX1.298325a7-f5f8-4b5e-b3da-dd9dab6e4820.svs in folder: 3b88b579-a27a-4ac4-8533-48dded7d11c7
# ⚠️ Skipping TCGA-AA-3530-01Z-00-DX1.298325a7-f5f8-4b5e-b3da-dd9dab6e4820.svs: Not found or invalid in metadata.
# Count: 159
#
# 🚀 Starting processing of: TCGA-AG-3583-01Z-00-DX1.7f30dd92-a80b-4090-82ca-7ea8e0a14094.svs in folder: 3bc2da63-a087-43d6-ba3f-37544dc6a2ac
# ⚠️ Skipping TCGA-AG-3583-01Z-00-DX1.7f30dd92-a80b-4090-82ca-7ea8e0a14094.svs: Not found or invalid in metadata.
# Count: 160
#
# 🚀 Starting processing of: TCGA-G4-6309-01Z-00-DX1.3eb20fdc-eb86-4bd5-8194-76b02d4fa472.svs in folder: 3bcf18c0-708e-45ca-bd05-99ceca10dbfe
# File already exists
# Count: 161
#
# 🚀 Starting processing of: TCGA-NH-A6GC-06Z-00-DX1.5F90CBDB-794B-498D-B75F-60EBDE17B22A.svs in folder: 3c258af5-5104-48f2-97e0-e5e61c27d0d3
# File already exists
# Count: 162
#
# 🚀 Starting processing of: TCGA-AA-3939-01Z-00-DX1.6ceb6e8f-a469-4f42-9597-8bf853d95640.svs in folder: 3c964c2b-607a-437e-8fe2-3998850f9689
# ⚠️ Skipping TCGA-AA-3939-01Z-00-DX1.6ceb6e8f-a469-4f42-9597-8bf853d95640.svs: Not found or invalid in metadata.
# Count: 163
#
# 🚀 Starting processing of: TCGA-AG-3587-01Z-00-DX1.0be1e75e-2c95-406e-bece-b9f5e971be80.svs in folder: 3d50af91-6fc3-44ab-bcfb-7206c371ec8e
# ⚠️ Skipping TCGA-AG-3587-01Z-00-DX1.0be1e75e-2c95-406e-bece-b9f5e971be80.svs: Not found or invalid in metadata.
# Count: 164
#
# 🚀 Starting processing of: TCGA-AF-2692-01Z-00-DX1.101b23cb-53ab-4ec7-a4b5-8c6cf575c0f2.svs in folder: 3d64b1c9-f8f5-427c-8c38-4c9d22f8d5fd
# ⚠️ Skipping TCGA-AF-2692-01Z-00-DX1.101b23cb-53ab-4ec7-a4b5-8c6cf575c0f2.svs: Not found or invalid in metadata.
# Count: 165
#
# 🚀 Starting processing of: TCGA-AA-3811-01Z-00-DX1.369d7946-911e-4e97-8ae7-32ef12b6b106.svs in folder: 3da5c30e-042f-4dca-965e-0852ca2d8987
# File already exists
# Count: 166
#
# 🚀 Starting processing of: TCGA-SS-A7HO-01Z-00-DX1.D20B9109-F984-40DE-A4F1-2DFC61002862.svs in folder: 3db6186a-d812-4d9d-a7e8-a7f0c0aa140a
# File already exists
# Count: 167
#
# 🚀 Starting processing of: TCGA-AF-A56L-01Z-00-DX1.984FBEF1-A46B-432D-A295-1275E60D09D8.svs in folder: 3dd486c2-4ee8-4b4d-8e2e-0baa6b190dbc
# File already exists
# Count: 168
#
# 🚀 Starting processing of: TCGA-F5-6814-01Z-00-DX1.25b7eec3-80bc-43c2-9969-78f343c55bed.svs in folder: 3dd8502d-6972-41f6-8c96-bdd1ab17db44
# File already exists
# Count: 169
#
# 🚀 Starting processing of: TCGA-DY-A1DC-01Z-00-DX1.2DF22B63-011B-4530-ADE4-8245779EDB6F.svs in folder: 3de3d16d-fb2b-4b37-859e-8fd916f9d4f1
# File already exists
# Count: 170
#
# 🚀 Starting processing of: TCGA-D5-5541-01Z-00-DX1.2cd0a69e-879e-47aa-8035-1f9732ec4760.svs in folder: 3df01e75-ed41-46d9-bfd7-e09f1e935810
# File already exists
# Count: 171
#
# 🚀 Starting processing of: TCGA-A6-5660-01Z-00-DX1.b254e383-a889-4b73-8f91-8580c8285754.svs in folder: 3e1fc385-7eef-4d96-9735-a5c039286ee4
# File already exists
# Count: 172
#
# 🚀 Starting processing of: TCGA-QG-A5Z2-01Z-00-DX2.F2352352-8F00-4BB3-8A62-8D1C1E374F95.svs in folder: 3e405d04-ccc8-4757-9a70-d30f449e2548
# File already exists
# Count: 173
#
# 🚀 Starting processing of: TCGA-DM-A0XF-01Z-00-DX1.6FD3D3CF-A1E2-4F4E-BF02-F81B1A1061CC.svs in folder: 3f582038-6f0c-460b-9ff5-d0a46282e31d
# File already exists
# Count: 174
#
# 🚀 Starting processing of: TCGA-AG-4022-01Z-00-DX1.72c82ee1-ceb4-4247-813a-157e80cb5ab7.svs in folder: 3f66b98e-48b9-4f7d-81cd-6a306d5c2472
# File already exists
# Count: 175
#
# 🚀 Starting processing of: TCGA-QG-A5Z1-01Z-00-DX2.2CE72B6A-557F-43BD-BA4C-B252E14E46EF.svs in folder: 3f7b713c-e8b9-480d-a006-69ff3df858ff
# File already exists
# Count: 176
#
# 🚀 Starting processing of: TCGA-A6-5664-01Z-00-DX1.622f6650-1926-4fa2-b42b-74122d9a68a4.svs in folder: 3fa4a855-ff4c-4f82-a248-229b4668d3ae
# File already exists
# Count: 177
#
# 🚀 Starting processing of: TCGA-AA-3818-01Z-00-DX1.80d3eeeb-9a4d-4211-90e8-605a4b809a63.svs in folder: 41e7dc14-d609-4047-a89d-53f63eb25fee
# File already exists
# Count: 178
#
# 🚀 Starting processing of: TCGA-A6-2676-01Z-00-DX1.c465f6e0-b47c-48e9-bdb1-67077bb16c67.svs in folder: 42b1d9e6-a4c8-4625-b443-2bb2a5f69b02
# ⚠️ Skipping TCGA-A6-2676-01Z-00-DX1.c465f6e0-b47c-48e9-bdb1-67077bb16c67.svs: Not found or invalid in metadata.
# Count: 179
#
# 🚀 Starting processing of: TCGA-DC-6154-01Z-00-DX1.ea40ea43-062b-40e0-a572-90736551b355.svs in folder: 43264444-d202-4623-8142-a375b7686faf
# File already exists
# Count: 180
#
# 🚀 Starting processing of: TCGA-DM-A282-01Z-00-DX1.65f620ea-37be-4d3c-a993-a2bfb552108c.svs in folder: 43610e35-774c-43da-9053-742e286fa52c
# File already exists
# Count: 181
#
# 🚀 Starting processing of: TCGA-AG-3600-01Z-00-DX1.1d506eeb-bb65-4688-bdb2-6ac101fc1dbe.svs in folder: 439a42c5-1d03-4013-8db2-2694f72d26e1
# ⚠️ Skipping TCGA-AG-3600-01Z-00-DX1.1d506eeb-bb65-4688-bdb2-6ac101fc1dbe.svs: Not found or invalid in metadata.
# Count: 182
#
# 🚀 Starting processing of: TCGA-D5-6923-01Z-00-DX1.ad5211f6-32a3-42c6-8594-93cb4432b5f6.svs in folder: 45292bb4-733b-4636-ade7-4a8c6d6bfc16
# ⚠️ Skipping TCGA-D5-6923-01Z-00-DX1.ad5211f6-32a3-42c6-8594-93cb4432b5f6.svs: Not found or invalid in metadata.
# Count: 183
#
# 🚀 Starting processing of: TCGA-AZ-6607-01Z-00-DX1.b0a25161-7e13-42d6-9271-ecc5ecce2232.svs in folder: 45847d26-d445-4bcd-a9c8-5beb47cc5f8f
# ⚠️ Skipping TCGA-AZ-6607-01Z-00-DX1.b0a25161-7e13-42d6-9271-ecc5ecce2232.svs: Not found or invalid in metadata.
# Count: 184
#
# 🚀 Starting processing of: TCGA-EI-6512-01Z-00-DX1.edf24f1e-381b-4c14-aabc-9aa30e84c5d7.svs in folder: 458b0d34-ac90-4061-a810-e8f5a6d70423
# File already exists
# Count: 185
#
# 🚀 Starting processing of: TCGA-AA-3556-01Z-00-DX1.63a74b91-44e8-4ffd-8737-bcf6992183c3.svs in folder: 4610d8e4-ddc8-41e3-a92f-9cc32c8c8e8a
# ⚠️ Skipping TCGA-AA-3556-01Z-00-DX1.63a74b91-44e8-4ffd-8737-bcf6992183c3.svs: Not found or invalid in metadata.
# Count: 186
#
# 🚀 Starting processing of: TCGA-AG-3586-01Z-00-DX1.38d7b4ce-9f18-48e6-9988-a3ef43b3d646.svs in folder: 4724fc04-ae38-42c9-80c1-ff83d0de397f
# ⚠️ Skipping TCGA-AG-3586-01Z-00-DX1.38d7b4ce-9f18-48e6-9988-a3ef43b3d646.svs: Not found or invalid in metadata.
# Count: 187
#
# 🚀 Starting processing of: TCGA-DY-A0XA-01Z-00-DX1.6C98F8C6-0D17-4D7A-A404-B8E03E977D2B.svs in folder: 472b9ce6-fcf5-4104-b031-a37de733c9ec
# File already exists
# Count: 188
#
# 🚀 Starting processing of: TCGA-AA-A00E-01Z-00-DX1.ABFCAF2D-287A-445F-9F32-BD00D1B385C3.svs in folder: 4750c7b9-15c5-41c8-91cf-127b1cfbc78c
# ⚠️ Skipping TCGA-AA-A00E-01Z-00-DX1.ABFCAF2D-287A-445F-9F32-BD00D1B385C3.svs: Not found or invalid in metadata.
# Count: 189
#
# 🚀 Starting processing of: TCGA-AY-A69D-01Z-00-DX1.94582A46-7470-4265-8371-23BC246431EE.svs in folder: 477a0c14-bb53-4ef1-9441-d303aafb92dd
# File already exists
# Count: 190
#
# 🚀 Starting processing of: TCGA-F4-6461-01Z-00-DX1.f7da24ac-4a3c-4814-8d11-3138a954e0df.svs in folder: 48e8fd12-2a4a-4d83-905c-bd6f602af0be
# File already exists
# Count: 191
#
# 🚀 Starting processing of: TCGA-AA-3526-01Z-00-DX1.82876320-2866-4ffa-81d7-3278f7150fc3.svs in folder: 492e492d-6ab5-4fa7-97e1-9b1553d4337b
# ⚠️ Skipping TCGA-AA-3526-01Z-00-DX1.82876320-2866-4ffa-81d7-3278f7150fc3.svs: Not found or invalid in metadata.
# Count: 192
#
# 🚀 Starting processing of: TCGA-AA-A00L-01Z-00-DX1.4F57C465-BC1C-4774-B003-F7F29C6A69D0.svs in folder: 4942dd61-3a5c-4a6a-8808-22161577a630
# ⚠️ Skipping TCGA-AA-A00L-01Z-00-DX1.4F57C465-BC1C-4774-B003-F7F29C6A69D0.svs: Not found or invalid in metadata.
# Count: 193
#
# 🚀 Starting processing of: TCGA-AG-3882-01Z-00-DX1.b5c38e5d-6f16-4fdb-b01d-6c206892add4.svs in folder: 49dc9193-e2b5-4f24-a6af-4cb8980c1db1
# File already exists
# Count: 194
#
# 🚀 Starting processing of: TCGA-CM-6166-01Z-00-DX1.52eaa124-7ab5-4aaf-b074-7f89a4c53804.svs in folder: 49df964d-62da-429f-8700-3a5955ea4ef3
# File already exists
# Count: 195
#
# 🚀 Starting processing of: TCGA-DM-A1DA-01Z-00-DX1.00001FEF-3B63-4C6F-952A-1D5F6F51CD22.svs in folder: 4a3acf15-462d-44a3-b158-5dbda7a29860
# File already exists
# Count: 196
#
# 🚀 Starting processing of: TCGA-AA-3971-01Z-00-DX1.348b1114-a9d5-4a37-8dfd-3bc8738fec35.svs in folder: 4a644f46-af06-44ac-a7c6-f13258d70357
# File already exists
# Count: 197
#
# 🚀 Starting processing of: TCGA-AA-3516-01Z-00-DX1.0a9d9207-6dc2-44b9-89ea-16418430c484.svs in folder: 4b490e3e-5fa9-4656-9a37-9aec8c01133b
# ⚠️ Skipping TCGA-AA-3516-01Z-00-DX1.0a9d9207-6dc2-44b9-89ea-16418430c484.svs: Not found or invalid in metadata.
# Count: 198
#
# 🚀 Starting processing of: TCGA-CK-4951-01Z-00-DX1.abdbb15c-fd40-4a55-bf54-5668b3d4ea13.svs in folder: 4b7e4329-0b52-4304-9bf4-ebefa608a471
# File already exists
# Count: 199
#
# 🚀 Starting processing of: TCGA-AY-5543-01Z-00-DX1.f3614d19-8391-49cc-a0e4-932e717696d3.svs in folder: 4be5d625-9594-4bee-b6b2-2827ce65b473
# File already exists
# Count: 200
#
# 🚀 Starting processing of: TCGA-AG-4005-01Z-00-DX1.5df38ba5-00db-41b7-ae57-a62e28d94120.svs in folder: 4c386e32-e75e-4d28-9798-2fe93b9af935
# ⚠️ Skipping TCGA-AG-4005-01Z-00-DX1.5df38ba5-00db-41b7-ae57-a62e28d94120.svs: Not found or invalid in metadata.
# Count: 201
#
# 🚀 Starting processing of: TCGA-A6-3809-01Z-00-DX1.c26f03e8-c285-4a66-925d-ae9cba17d7b3.svs in folder: 4c4f4942-530b-4043-84b9-785b4b3e9dba
# ⚠️ Skipping TCGA-A6-3809-01Z-00-DX1.c26f03e8-c285-4a66-925d-ae9cba17d7b3.svs: Not found or invalid in metadata.
# Count: 202
#
# 🚀 Starting processing of: TCGA-AD-6889-01Z-00-DX1.5269A81E-5391-4875-8F2A-6505BC5BBFD9.svs in folder: 4d52a92f-7495-41ec-8606-5fff12413940
# File already exists
# Count: 203
#
# 🚀 Starting processing of: TCGA-F4-6704-01Z-00-DX1.f7cb6641-a6f3-40b7-a5cb-aaf604f73d0f.svs in folder: 4e9db2f2-606c-47ac-9861-a6efde2766d0
# File already exists
# Count: 204
#
# 🚀 Starting processing of: TCGA-A6-2684-01Z-00-DX1.be127778-e160-4ae3-9e5a-13a16eae2e7a.svs in folder: 4f8edf30-a7bc-4a4a-a8bd-3af91fbddce2
# ⚠️ Skipping TCGA-A6-2684-01Z-00-DX1.be127778-e160-4ae3-9e5a-13a16eae2e7a.svs: Not found or invalid in metadata.
# Count: 205
#
# 🚀 Starting processing of: TCGA-CI-6622-01Z-00-DX1.58a0f078-4076-4c27-aabd-7a169ead5356.svs in folder: 4f97d5d7-011f-4461-97ca-ed5f7513f852
# File already exists
# Count: 206
#
# 🚀 Starting processing of: TCGA-EI-6507-01Z-00-DX1.d290617b-a289-4887-9c76-6482a23aebfb.svs in folder: 4fc8c650-54ea-4a89-aa61-e9b4c5b1758d
# File already exists
# Count: 207
#
# 🚀 Starting processing of: TCGA-G4-6628-01Z-00-DX1.d67973d1-9544-47e1-9ecb-e9d8d7f310e6.svs in folder: 507cdbcd-48ec-4fad-ab69-bf0ca8635f62
# File already exists
# Count: 208
#
# 🚀 Starting processing of: TCGA-G4-6323-01Z-00-DX1.f97c27a6-9fbe-4a81-b4aa-020c25279449.svs in folder: 50e5358f-6e30-4d47-8142-15a0cb821c49
# File already exists
# Count: 209
#
# 🚀 Starting processing of: TCGA-EI-6510-01Z-00-DX1.e1209172-b10e-4dca-a714-16960a498cf4.svs in folder: 5375a1ff-9c8e-4092-ba8e-625e45fd389a
# File already exists
# Count: 210
#
# 🚀 Starting processing of: TCGA-AA-3679-01Z-00-DX1.b3445f8e-b143-4f24-9edd-8abdcb6b139b.svs in folder: 53772800-a81b-4652-a891-6a9898de8283
# File already exists
# Count: 211
#
# 🚀 Starting processing of: TCGA-DC-6682-01Z-00-DX1.d5273947-536c-40d5-a1b4-2eb1dbc5d338.svs in folder: 54069ff1-89e9-4d9c-aaf7-d9aa011373be
# File already exists
# Count: 212
#
# 🚀 Starting processing of: TCGA-A6-6141-01Z-00-DX1.34b5db5c-74df-47d9-bb89-beec93ded868.svs in folder: 544b2a2e-17e4-4fde-b6ca-696d6dde973e
# ⚠️ Skipping TCGA-A6-6141-01Z-00-DX1.34b5db5c-74df-47d9-bb89-beec93ded868.svs: Not found or invalid in metadata.
# Count: 213
#
# 🚀 Starting processing of: TCGA-AG-3599-01Z-00-DX1.5cfa9ea3-683f-4994-b7e8-a7493914ac97.svs in folder: 549d1942-3c26-4452-9fab-de95e0810f2a
# ⚠️ Skipping TCGA-AG-3599-01Z-00-DX1.5cfa9ea3-683f-4994-b7e8-a7493914ac97.svs: Not found or invalid in metadata.
# Count: 214
#
# 🚀 Starting processing of: TCGA-AG-A00C-01Z-00-DX1.B0CCAC43-A39D-4C59-AFC6-003BF0958B45.svs in folder: 55881486-5ff4-404f-853f-b0d604ab512e
# File already exists
# Count: 215
#
# 🚀 Starting processing of: TCGA-DM-A0XD-01Z-00-DX1.DAFA56D4-85CB-4FB1-B5BB-E993CA522FF8.svs in folder: 5630d41c-57aa-4049-b4d5-a2a7b84b7b4a
# File already exists
# Count: 216
#
# 🚀 Starting processing of: TCGA-AA-3846-01Z-00-DX1.d6233d91-4d33-424a-99c1-8173fbeb5090.svs in folder: 565a064e-24e6-4981-b6d0-03e15fff255d
# File already exists
# Count: 217
#
# 🚀 Starting processing of: TCGA-AA-3514-01Z-00-DX1.9e135da2-436e-47e3-9dbf-b2f577677828.svs in folder: 567492c8-a39d-4a87-a569-b1a6537a1815
# ⚠️ Skipping TCGA-AA-3514-01Z-00-DX1.9e135da2-436e-47e3-9dbf-b2f577677828.svs: Not found or invalid in metadata.
# Count: 218
#
# 🚀 Starting processing of: TCGA-AD-6965-01Z-00-DX1.0330727c-42f5-4a08-a35d-af81eda1d0f1.svs in folder: 56b13994-61dd-4f3b-b26f-faacf93a339d
# File already exists
# Count: 219
#
# 🚀 Starting processing of: TCGA-AG-3909-01Z-00-DX1.adb4e65f-e23f-409c-8886-bbdcaa52d1d4.svs in folder: 56b51028-68fa-40ef-a01c-0cfbb1db3fa9
# File already exists
# Count: 220
#
# 🚀 Starting processing of: TCGA-AZ-4616-01Z-00-DX1.0a0f6eaa-4db6-4479-a9df-f09387f555b1.svs in folder: 5783bad7-1d94-4257-a234-af0330b96ad9
# File already exists
# Count: 221
#
# 🚀 Starting processing of: TCGA-CK-4952-01Z-00-DX1.0e98c7b4-5f80-485d-a191-ad93564b5f96.svs in folder: 5794786f-1632-4ec6-8a92-2430c9564260
# File already exists
# Count: 222
#
# 🚀 Starting processing of: TCGA-CM-5864-01Z-00-DX1.2cb87875-6cae-4d8e-9c93-4a83941c0ca9.svs in folder: 57c2d0c6-5dfa-4c95-982c-6c189d9b9ad6
# File already exists
# Count: 223
#
# 🚀 Starting processing of: TCGA-CA-5797-01Z-00-DX1.6549a80e-4b68-4147-949b-6149ab680313.svs in folder: 5858e780-9a2b-4020-bc48-924d974d9344
# File already exists
# Count: 224
#
# 🚀 Starting processing of: TCGA-AZ-6601-01Z-00-DX1.40681471-3104-48be-8b57-55dba1f432f8.svs in folder: 588d5512-9711-4285-83b4-14bb1c3b6514
# ⚠️ Skipping TCGA-AZ-6601-01Z-00-DX1.40681471-3104-48be-8b57-55dba1f432f8.svs: Not found or invalid in metadata.
# Count: 225
#
# 🚀 Starting processing of: TCGA-AF-6672-01Z-00-DX1.a966d993-8a84-4175-b456-77816c3c4793.svs in folder: 5917f1a4-2a43-49e6-9a6e-33cd35fc1616
# File already exists
# Count: 226
#
# 🚀 Starting processing of: TCGA-AG-A01N-01Z-00-DX1.E2436F26-E5BE-446A-8F90-0867EA07381A.svs in folder: 5a111dd2-e5dd-475e-9f31-a06985047d34
# File already exists
# Count: 227
#
# 🚀 Starting processing of: TCGA-DM-A1D9-01Z-00-DX1.C286F663-142A-4F8E-BFCD-56E33F73F7E8.svs in folder: 5a2d15f8-078a-41df-9610-63a7ce6b1195
# File already exists
# Count: 228
#
# 🚀 Starting processing of: TCGA-AG-3608-01Z-00-DX1.aabf7424-6c66-489d-9715-8632d9a17cfc.svs in folder: 5a3cd58b-f6ea-43fe-8a3d-1dcac76c3514
# ⚠️ Skipping TCGA-AG-3608-01Z-00-DX1.aabf7424-6c66-489d-9715-8632d9a17cfc.svs: Not found or invalid in metadata.
# Count: 229
#
# 🚀 Starting processing of: TCGA-G5-6572-01Z-00-DX1.7a9d5e04-f3dc-4fc7-b188-b90219e0cc50.svs in folder: 5a966eb4-241c-4f5c-9cb7-7b5e5698f26a
# ⚠️ Skipping TCGA-G5-6572-01Z-00-DX1.7a9d5e04-f3dc-4fc7-b188-b90219e0cc50.svs: Not found or invalid in metadata.
# Count: 230
#
# 🚀 Starting processing of: TCGA-AA-3548-01Z-00-DX1.41949ab5-79f2-4729-9d54-c0fca1daf124.svs in folder: 5aa1b035-0a9e-4245-abba-2ad841f6955a
# ⚠️ Skipping TCGA-AA-3548-01Z-00-DX1.41949ab5-79f2-4729-9d54-c0fca1daf124.svs: Not found or invalid in metadata.
# Count: 231
#
# 🚀 Starting processing of: TCGA-5M-AATE-01Z-00-DX1.483FFD2F-61A1-477E-8F94-157383803FC7.svs in folder: 5ad0faff-3ea0-46da-8b6b-a7c70d61fbec
# File already exists
# Count: 232
#
# 🚀 Starting processing of: TCGA-AY-A71X-01Z-00-DX1.68F9BC0F-1D60-4AEF-9083-509387038F03.svs in folder: 5af6b02b-f142-41f7-a1a4-1fd61dc73f3e
# File already exists
# Count: 233
#
# 🚀 Starting processing of: TCGA-AD-6888-01Z-00-DX1.47AE342C-4577-4D8B-9048-0B106C5960E7.svs in folder: 5ba7738a-dd63-4c39-b48d-7b9c28be1d7d
# File already exists
# Count: 234
#
# 🚀 Starting processing of: TCGA-CI-6624-01Z-00-DX1.d8ee9c79-5886-41f1-a10a-3da167933882.svs in folder: 5be610d0-3e07-4f52-8239-1ee4d3c9e741
# File already exists
# Count: 235
#
# 🚀 Starting processing of: TCGA-F5-6863-01Z-00-DX1.67a42867-9ef3-4422-a20b-f9091d3517ed.svs in folder: 5c39c2cf-70c0-49b4-9c94-9b9e6c1013ac
# File already exists
# Count: 236
#
# 🚀 Starting processing of: TCGA-AA-A00R-01Z-00-DX1.7520405C-E7DD-46A4-BB68-ADFA511AEA64.svs in folder: 5c5928b2-a799-4159-b895-191ee8ebdba5
# ⚠️ Skipping TCGA-AA-A00R-01Z-00-DX1.7520405C-E7DD-46A4-BB68-ADFA511AEA64.svs: Not found or invalid in metadata.
# Count: 237
#
# 🚀 Starting processing of: TCGA-CK-6748-01Z-00-DX1.1dd76660-7858-470c-a27b-36586b788125.svs in folder: 5c7c8d94-86ce-4db2-8d05-e7d215c1bf2f
# File already exists
# Count: 238
#
# 🚀 Starting processing of: TCGA-EI-6884-01Z-00-DX1.45c3bfa8-e7c2-4943-b5fe-2a2587b75f55.svs in folder: 5d43546e-1323-442d-8c52-b3ab0c85dad1
# File already exists
# Count: 239
#
# ...
# Count: 541
#
# 🚀 Starting processing of: TCGA-F4-6855-01Z-00-DX1.41ed5985-be19-4dce-aab6-de3be0f1dcca.svs in folder: df076968-bcb9-4d39-918d-a6775020cd60
# File already exists
# Count: 542
#
# 🚀 Starting processing of: TCGA-AA-A00J-01Z-00-DX1.BA85D337-6687-44A6-A8DD-0CE889134BA0.svs in folder: df3708ed-f6bd-464a-9717-360ab5877e10
# ⚠️ Skipping TCGA-AA-A00J-01Z-00-DX1.BA85D337-6687-44A6-A8DD-0CE889134BA0.svs: Not found or invalid in metadata.
# Count: 543
#
# 🚀 Starting processing of: TCGA-EI-6514-01Z-00-DX1.d31b7dc9-3024-419e-a60d-53385e59369f.svs in folder: df710d65-9312-4be4-a0c4-2a7cd383cd36
# File already exists
# Count: 544
#
# 🚀 Starting processing of: TCGA-AA-3812-01Z-00-DX1.c501fc71-8370-4034-b32a-1bb7cd846881.svs in folder: df7eff22-a7b7-470a-877b-c4cbbc7020fe
# File already exists
# Count: 545
#
# 🚀 Starting processing of: TCGA-4N-A93T-01Z-00-DX1.82E240B1-22C3-46E3-891F-0DCE35C43F8B.svs in folder: dffdc56e-f1f5-4a1b-a16b-561462b3b740
# File already exists
# Count: 546
#
# 🚀 Starting processing of: TCGA-AA-3562-01Z-00-DX1.e07893e6-646d-41b5-be51-9c19d51f6743.svs in folder: e0057043-fae2-4b6b-8298-1d06e48100e3
# ⚠️ Skipping TCGA-AA-3562-01Z-00-DX1.e07893e6-646d-41b5-be51-9c19d51f6743.svs: Not found or invalid in metadata.
# Count: 547
#
# 🚀 Starting processing of: TCGA-EI-7002-01Z-00-DX1.3f2935be-16fc-4a41-990a-8ab7f8fe6c85.svs in folder: e09f4cd8-a80f-472c-a54a-8968ff0f04d1
# File already exists
# Count: 548
#
# 🚀 Starting processing of: TCGA-G4-6310-01Z-00-DX1.b88472d4-3adc-4e4d-b0f2-0dc195a3d7df.svs in folder: e1072fe7-d1c9-4a70-be92-cbb111223d98
# ⚠️ Skipping TCGA-G4-6310-01Z-00-DX1.b88472d4-3adc-4e4d-b0f2-0dc195a3d7df.svs: Not found or invalid in metadata.
# Count: 549
#
# 🚀 Starting processing of: TCGA-AG-3584-01Z-00-DX1.0ebb5f29-445f-48e1-99f2-ac261080e53d.svs in folder: e1609319-2333-465c-b46e-e63490df2890
# ⚠️ Skipping TCGA-AG-3584-01Z-00-DX1.0ebb5f29-445f-48e1-99f2-ac261080e53d.svs: Not found or invalid in metadata.
# Count: 550
#
# 🚀 Starting processing of: TCGA-DM-A28H-01Z-00-DX1.daf607db-57d0-4685-8dd1-f6d0a9ee0435.svs in folder: e1a7d9a2-48db-41f7-8548-ca8ac936d22d
# File already exists
# Count: 551
#
# 🚀 Starting processing of: TCGA-AA-A01X-01Z-00-DX1.7433F54C-2A79-467A-8FEA-638AE48F42A0.svs in folder: e21c8190-ca2b-424e-811d-98cd24814bda
# File already exists
# Count: 552
#
# 🚀 Starting processing of: TCGA-AA-3984-01Z-00-DX1.d0cb7571-c612-4410-ac03-ebe800ad6767.svs in folder: e2663d91-94f9-48dd-8680-3803ede25421
# File already exists
# Count: 553
#
# 🚀 Starting processing of: TCGA-AF-A56N-01Z-00-DX1.513ABBD0-9CF9-42EE-8C8C-039BAF96CFF0.svs in folder: e295d73d-22a9-4767-9005-1ca2ead046b6
# File already exists
# Count: 554
#
# 🚀 Starting processing of: TCGA-AG-A036-01Z-00-DX1.8D306B77-755A-4FDC-BE9C-C407716FB142.svs in folder: e29aa6d7-5bc9-4276-ba77-d9a964e9c374
# ⚠️ Skipping TCGA-AG-A036-01Z-00-DX1.8D306B77-755A-4FDC-BE9C-C407716FB142.svs: Not found or invalid in metadata.
# Count: 555
#
# 🚀 Starting processing of: TCGA-AG-3582-01Z-00-DX1.2e248185-2230-479d-806e-d6687dcb70c3.svs in folder: e2ceace7-0a59-4873-bef1-cb4d7d92fe55
# ⚠️ Skipping TCGA-AG-3582-01Z-00-DX1.2e248185-2230-479d-806e-d6687dcb70c3.svs: Not found or invalid in metadata.
# Count: 556
#
# 🚀 Starting processing of: TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-9453-05476da34cdd.svs in folder: e329f6c8-9bb9-4717-83ce-ae378a509b83
# ⚠️ Skipping TCGA-AA-3553-01Z-00-DX1.45a24cd4-6eb2-4f20-9453-05476da34cdd.svs: Not found or invalid in metadata.
# Count: 557
#
# 🚀 Starting processing of: TCGA-DC-6156-01Z-00-DX1.102feb5c-0dff-4d7b-9b3b-d66383e8a4ff.svs in folder: e4055eb6-a5ba-4a5b-825e-c7154967772b
# ⚠️ Skipping TCGA-DC-6156-01Z-00-DX1.102feb5c-0dff-4d7b-9b3b-d66383e8a4ff.svs: Not found or invalid in metadata.
# Count: 558
#
# 🚀 Starting processing of: TCGA-AG-3612-01Z-00-DX1.4d866e62-3135-4562-83e1-3629a5c2a744.svs in folder: e4125f97-b1c5-4152-93eb-820041fd88c9
# ⚠️ Skipping TCGA-AG-3612-01Z-00-DX1.4d866e62-3135-4562-83e1-3629a5c2a744.svs: Not found or invalid in metadata.
# Count: 559
#
# 🚀 Starting processing of: TCGA-CM-6165-01Z-00-DX1.d59faefa-f647-4617-9dcf-4fd6ab45b4e6.svs in folder: e4423a3b-d74a-4b89-93bc-27ca11d2c6ee
# File already exists
# Count: 560
#
# 🚀 Starting processing of: TCGA-A6-2671-01Z-00-DX1.13d1a0d9-78cd-4cfc-b670-34a79ebe52ee.svs in folder: e45b588f-c7db-4cea-a78c-bfecd1a46da6
# File already exists
# Count: 561
#
# 🚀 Starting processing of: TCGA-D5-6898-01Z-00-DX1.d2c5ab3b-da4d-4fa4-b535-4339d59515e7.svs in folder: e4fadd85-32b8-4ac0-a5d5-8f09c5c60f1f
# File already exists
# Count: 562
#
# 🚀 Starting processing of: TCGA-A6-6142-01Z-00-DX1.e923ce20-d3c3-4d21-9e7c-d999a3742f9b.svs in folder: e51eb325-b534-42d8-882a-653161d32487
# File already exists
# Count: 563
#
# 🚀 Starting processing of: TCGA-D5-6533-01Z-00-DX1.a4b5096e-88cc-4797-b8d5-1a9cf1e74a55.svs in folder: e5315d4a-f1fa-452c-87ca-0a26668da9da
# File already exists
# Count: 564
#
# 🚀 Starting processing of: TCGA-NH-A8F8-01Z-00-DX1.0C13D583-0BCE-44F7-A4E6-5994FE97B99C.svs in folder: e592fc48-a4b8-4e73-9307-4fc462e6eda5
# File already exists
# Count: 565
#
# 🚀 Starting processing of: TCGA-5M-AAT6-01Z-00-DX1.8834C952-14E3-4491-8156-52FC917BB014.svs in folder: e5d2f743-a51f-4ba7-a23d-e87a069a7ee1
# File already exists
# Count: 566
#
# 🚀 Starting processing of: TCGA-D5-7000-01Z-00-DX1.fb08c430-2c8c-486b-a39d-7d28c5eae189.svs in folder: e6088bd0-2ef5-44f1-9111-62e10b8922ab
# File already exists
# Count: 567
#
# 🚀 Starting processing of: TCGA-CM-6164-01Z-00-DX1.ccf5ce96-b732-4c35-b177-d3dbe2ed89cb.svs in folder: e72187ad-1c39-4191-9379-e6d8392a6af9
# File already exists
# Count: 568
#
# 🚀 Starting processing of: TCGA-DC-5337-01Z-00-DX1.5ef2af22-210a-4767-a12b-92af0376c505.svs in folder: e7887760-2db7-438b-9ed5-c13b8e2a27d2
# File already exists
# Count: 569
#
# 🚀 Starting processing of: TCGA-AY-6386-01Z-00-DX1.2B976983-5724-4335-8B47-9B44271B0A01.svs in folder: e79cfeea-cbff-46fa-8538-7f2527af70aa
# File already exists
# Count: 570
#
# 🚀 Starting processing of: TCGA-AG-3578-01Z-00-DX1.fa579e93-e28c-4e38-8757-bd8fa1c00285.svs in folder: e8526fde-904f-46aa-92c1-2ea311199407
# ⚠️ Skipping TCGA-AG-3578-01Z-00-DX1.fa579e93-e28c-4e38-8757-bd8fa1c00285.svs: Not found or invalid in metadata.
# Count: 571
#
# 🚀 Starting processing of: TCGA-AG-A025-01Z-00-DX1.D7F8C795-37A3-4FB5-888F-B81F4DFE94FA.svs in folder: e8daaa27-2993-4677-9f81-5f6acefdbb6b
# ⚠️ Skipping TCGA-AG-A025-01Z-00-DX1.D7F8C795-37A3-4FB5-888F-B81F4DFE94FA.svs: Not found or invalid in metadata.
# Count: 572
#
# 🚀 Starting processing of: TCGA-AA-A02H-01Z-00-DX1.5343879F-6C5D-48B3-8D78-D895ED118F42.svs in folder: e95e537b-3824-421d-9003-4a6e39a0a342
# File already exists
# Count: 573
#
# 🚀 Starting processing of: TCGA-NH-A6GC-01Z-00-DX1.29073D7E-5EEF-4BBA-96BE-DC8C69924C42.svs in folder: ea9736d6-504b-458a-9361-605ce755aef6
# File already exists
# Count: 574
#
# 🚀 Starting processing of: TCGA-AD-6964-01Z-00-DX1.83AF88B9-C59B-48C6-A739-85ACB8F8ECA9.svs in folder: eb10274f-9337-4ef0-9762-5430ede6d6f9
# File already exists
# Count: 575
#
# 🚀 Starting processing of: TCGA-D5-6538-01Z-00-DX1.fab8da8e-1e0a-4fb2-987c-9792c05d5a3a.svs in folder: eb3a8b3e-fcd9-446b-b851-f6880ad9b3f5
# File already exists
# Count: 576
#
# 🚀 Starting processing of: TCGA-AA-3544-01Z-00-DX1.96850cbf-2305-4b65-8f06-db801af51cc3.svs in folder: ec1f4d29-4b67-420f-9bba-9138b5d64d4e
# ⚠️ Skipping TCGA-AA-3544-01Z-00-DX1.96850cbf-2305-4b65-8f06-db801af51cc3.svs: Not found or invalid in metadata.
# Count: 577
#
# 🚀 Starting processing of: TCGA-AF-6136-01Z-00-DX1.a0e22964-b7b4-43ba-bfa1-11c60f254eb3.svs in folder: ec1f9ff4-f634-42fb-9c64-dee4950df4df
# File already exists
# Count: 578
#
# 🚀 Starting processing of: TCGA-AH-6644-01Z-00-DX1.382b842a-afd7-430b-8489-502c8ab88ee1.svs in folder: ec3f1820-d62d-4b74-927f-4cd3c90a247d
# File already exists
# Count: 579
#
# 🚀 Starting processing of: TCGA-DM-A288-01Z-00-DX1.716efd68-52d4-4049-b9a6-480700579e74.svs in folder: ec5b592f-8203-451a-8491-5998c12a5355
# File already exists
# Count: 580
#
# 🚀 Starting processing of: TCGA-AD-6901-01Z-00-DX1.0a69c0b5-6238-4c1a-bbbd-ea743bf6fc98.svs in folder: ed500fa9-70b1-4d52-9e73-d8d512448901
# File already exists
# Count: 581
#
# 🚀 Starting processing of: TCGA-3L-AA1B-01Z-00-DX1.8923A151-A690-40B7-9E5A-FCBEDFC2394F.svs in folder: ed5f8c30-29e3-4144-948b-b8658564f2d6
# File already exists
# Count: 582
#
# 🚀 Starting processing of: TCGA-CM-4746-01Z-00-DX1.c83b9795-bf45-4100-9052-a7e485e0f770.svs in folder: ed7c20f8-e2a0-4a07-baaf-5002433d8c0c
# File already exists
# Count: 583
#
# 🚀 Starting processing of: TCGA-AG-3898-01Z-00-DX1.c71a46ab-8ce8-48a6-8b06-f5f7995efc95.svs in folder: ee961bbb-27bf-4213-be09-54e6bc89a626
# File already exists
# Count: 584
#
# 🚀 Starting processing of: TCGA-NH-A50U-01Z-00-DX1.CA30EE72-7149-44E0-9082-AC1922ADDB09.svs in folder: eebf2fbf-1fbe-4784-a37f-29434f8c00dc
# File already exists
# Count: 585
#
# 🚀 Starting processing of: TCGA-NH-A50T-01Z-00-DX1.4624B690-C0DE-42BD-852C-6EBABF40255F.svs in folder: eedce645-a8d2-4fa7-9a68-db5e96fa4920
# File already exists
# Count: 586
#
# 🚀 Starting processing of: TCGA-AA-3841-01Z-00-DX1.10f98d09-027f-4495-9ad8-7c8dc49a07d7.svs in folder: eef92134-10aa-4c76-9cbb-5f721b9b39e6
# ⚠️ Skipping TCGA-AA-3841-01Z-00-DX1.10f98d09-027f-4495-9ad8-7c8dc49a07d7.svs: Not found or invalid in metadata.
# Count: 587
#
# 🚀 Starting processing of: TCGA-G4-6627-01Z-00-DX1.f23c6977-d0cb-4bc8-b373-4b1b73c331cc.svs in folder: ef497638-68a8-40f4-b321-61bd559c010b
# File already exists
# Count: 588
#
# 🚀 Starting processing of: TCGA-AA-A01D-01Z-00-DX1.A6FE424C-9BF8-4605-8A78-7BD7B83BEC61.svs in folder: ef52da91-023b-45be-ac86-22f4e051ff2c
# ⚠️ Skipping TCGA-AA-A01D-01Z-00-DX1.A6FE424C-9BF8-4605-8A78-7BD7B83BEC61.svs: Not found or invalid in metadata.
# Count: 589
#
# 🚀 Starting processing of: TCGA-CA-6719-01Z-00-DX1.590fea56-aae4-4108-9169-a67ec8cd95b7.svs in folder: ef9e8336-1099-42ae-aa5e-56ef59d3da3a
# File already exists
# Count: 590
#
# 🚀 Starting processing of: TCGA-AA-3496-01Z-00-DX1.B109A6F3-02E0-4181-B69A-00CBA758C074.svs in folder: efd81ef1-0260-4e2c-ad3e-64733b3072a2
# ⚠️ Skipping TCGA-AA-3496-01Z-00-DX1.B109A6F3-02E0-4181-B69A-00CBA758C074.svs: Not found or invalid in metadata.
# Count: 591
#
# 🚀 Starting processing of: TCGA-EI-6506-01Z-00-DX1.5a936d3f-6209-4931-85b0-35431302fd71.svs in folder: efe6a14d-2f1a-4483-8d9f-2d9796108882
# File already exists
# Count: 592
# ❌ No .svs file found in: D:/Aamir Gulzar/WSI_Raw_data\extensions
# Count: 593
#
# 🚀 Starting processing of: TCGA-AG-3594-01Z-00-DX1.83a27a62-0ddd-48e0-ba34-1ba6d8aa9526.svs in folder: f0ad6d86-2925-493f-8ef5-b88e592ea2da
# ⚠️ Skipping TCGA-AG-3594-01Z-00-DX1.83a27a62-0ddd-48e0-ba34-1ba6d8aa9526.svs: Not found or invalid in metadata.
# Count: 594
#
# 🚀 Starting processing of: TCGA-QG-A5YW-01Z-00-DX1.3242285F-FA82-4A92-9D0E-951013A3C91A.svs in folder: f0c120bf-849d-4cf4-bcc5-ed2abf7d522f
# File already exists
# Count: 595
#
# 🚀 Starting processing of: TCGA-AA-3968-01Z-00-DX1.54b76478-a822-49b5-8286-dcbbb2fba2f8.svs in folder: f14a4926-7285-4e18-bf48-5fd7f27c6823
# File already exists
# Count: 596
#
# 🚀 Starting processing of: TCGA-F5-6465-01Z-00-DX1.e0c7afc7-1904-4dc4-8e8a-83b4290f445f.svs in folder: f1755d9f-844a-4a20-9748-a1f2bea401df
# File already exists
# Count: 597
#
# 🚀 Starting processing of: TCGA-AA-A01I-01Z-00-DX1.D24F43B2-F46E-4F7F-85A0-91F3A04E0785.svs in folder: f1a82927-49c3-4fd1-963a-1e24e1d8e9ab
# ⚠️ Skipping TCGA-AA-A01I-01Z-00-DX1.D24F43B2-F46E-4F7F-85A0-91F3A04E0785.svs: Not found or invalid in metadata.
# Count: 598
#
# 🚀 Starting processing of: TCGA-WS-AB45-01Z-00-DX1.1FD99E7A-830F-40DC-98CD-53C62C678AC6.svs in folder: f1d67a87-f8cd-49e7-803b-e686e5aee85f
# File already exists
# Count: 599
#
# 🚀 Starting processing of: TCGA-G5-6235-01Z-00-DX1.c78c95d4-933c-4057-81a4-2fab3ee4a187.svs in folder: f34d2bfb-b597-4b2b-8562-ca8bb5704f25
# ⚠️ Skipping TCGA-G5-6235-01Z-00-DX1.c78c95d4-933c-4057-81a4-2fab3ee4a187.svs: Not found or invalid in metadata.
# Count: 600
#
# 🚀 Starting processing of: TCGA-A6-2680-01Z-00-DX1.7b77c0fb-f51d-4d16-ae77-f7615b1d0b87.svs in folder: f373057a-ac13-4a03-9194-58c2c67ccee5
# ⚠️ Skipping TCGA-A6-2680-01Z-00-DX1.7b77c0fb-f51d-4d16-ae77-f7615b1d0b87.svs: Not found or invalid in metadata.
# Count: 601
#
# 🚀 Starting processing of: TCGA-D5-6532-01Z-00-DX1.a28f2969-31ae-408f-99f5-5428e183e123.svs in folder: f3e1b482-623f-473b-961f-e8ed85dea2c0
# File already exists
# Count: 602
#
# 🚀 Starting processing of: TCGA-AA-3554-01Z-00-DX1.53ea377e-6671-47bb-a2b6-b136d9686144.svs in folder: f42d95c6-a82d-41fe-a76e-3248592e0bc3
# ⚠️ Skipping TCGA-AA-3554-01Z-00-DX1.53ea377e-6671-47bb-a2b6-b136d9686144.svs: Not found or invalid in metadata.
# Count: 603
#
# 🚀 Starting processing of: TCGA-QG-A5Z2-01Z-00-DX1.51896C31-235E-48EF-90F7-FC05350CA564.svs in folder: f4e7f126-b2e2-4e0e-b7cc-4bf4df4656f9
# File already exists
# Count: 604
#
# 🚀 Starting processing of: TCGA-AG-3593-01Z-00-DX1.d3086414-77f4-483f-bac8-d7cb29a0689e.svs in folder: f51f1618-a90f-461e-9f55-b0a1f91c9350
# ⚠️ Skipping TCGA-AG-3593-01Z-00-DX1.d3086414-77f4-483f-bac8-d7cb29a0689e.svs: Not found or invalid in metadata.
# Count: 605
#
# 🚀 Starting processing of: TCGA-AA-A02W-01Z-00-DX1.3D9DD408-C389-411D-B4AC-6DC531D35BAD.svs in folder: f60984ad-aef4-454d-acc2-28886772f55b
# ⚠️ Skipping TCGA-AA-A02W-01Z-00-DX1.3D9DD408-C389-411D-B4AC-6DC531D35BAD.svs: Not found or invalid in metadata.
# Count: 606
#
# 🚀 Starting processing of: TCGA-CM-6169-01Z-00-DX1.0381c243-02b8-4f1d-840c-19ef44d4b92c.svs in folder: f60ff5bf-405c-482f-9bac-12056d3f4215
# File already exists
# Count: 607
#
# 🚀 Starting processing of: TCGA-D5-6531-01Z-00-DX1.32241731-5890-424e-96d5-b897e770f03c.svs in folder: f6109ea3-6f3e-477d-9353-c08dcce93454
# File already exists
# Count: 608
#
# 🚀 Starting processing of: TCGA-QG-A5YV-01Z-00-DX1.9B7FD3EA-D1AB-44B3-B728-820939EF56EA.svs in folder: f69aeb1a-626a-4dfa-bf5f-60ff674f26aa
# File already exists
# Count: 609
#
# 🚀 Starting processing of: TCGA-AZ-4308-01Z-00-DX1.804e054d-e206-4b34-a992-86317ef515d9.svs in folder: f6c772bc-2678-4808-9821-0cd9405b868b
# File already exists
# Count: 610
#
# 🚀 Starting processing of: TCGA-AD-6895-01Z-00-DX1.7FB1FBC6-683B-4285-89D1-A7A20F07A9D4.svs in folder: f77be3ea-4595-49a6-b41c-de074b132bf8
# ⚠️ Skipping TCGA-AD-6895-01Z-00-DX1.7FB1FBC6-683B-4285-89D1-A7A20F07A9D4.svs: Not found or invalid in metadata.
# Count: 611
#
# 🚀 Starting processing of: TCGA-A6-2681-01Z-00-DX1.5e11f090-a19d-4d5c-bcf6-c219b55d02bc.svs in folder: f7d4a000-4473-4d7b-9980-c495428eaa50
# File already exists
# Count: 612
#
# 🚀 Starting processing of: TCGA-AA-3833-01Z-00-DX1.d27bd30c-bba2-4621-8157-feb28ba2e241.svs in folder: f8ec6630-7642-4e41-9975-7f171710fde2
# File already exists
# Count: 613
#
# 🚀 Starting processing of: TCGA-AA-3685-01Z-00-DX1.57ef312b-70e0-46f5-b847-0e0ac32f1824.svs in folder: f94393a0-f0a4-44bb-9350-417c63cba839
# ⚠️ Skipping TCGA-AA-3685-01Z-00-DX1.57ef312b-70e0-46f5-b847-0e0ac32f1824.svs: Not found or invalid in metadata.
# Count: 614
#
# 🚀 Starting processing of: TCGA-AA-3492-01Z-00-DX1.32D79909-71D5-4843-847E-AECA5DBC963D.svs in folder: fa3a810e-09c6-4342-8923-1fe70546d9de
# ⚠️ Skipping TCGA-AA-3492-01Z-00-DX1.32D79909-71D5-4843-847E-AECA5DBC963D.svs: Not found or invalid in metadata.
# Count: 615
#
# 🚀 Starting processing of: TCGA-AA-A03F-01Z-00-DX1.8E1A83FE-2C85-4444-A8FC-D0691817968A.svs in folder: fac4903a-786f-4976-a7c4-6fce3f27e83f
# File already exists
# Count: 616
#
# 🚀 Starting processing of: TCGA-A6-6137-01Z-00-DX1.f50ab63c-05b0-49ea-9ceb-ed10cd6dc027.svs in folder: faee5ad2-300c-481f-ac93-86d074775f04
# File already exists
# Count: 617
#
# 🚀 Starting processing of: TCGA-AA-A01S-01Z-00-DX1.1F2812C1-9807-4D14-8071-3FE15236EB44.svs in folder: fb848c34-7a87-4e1b-9e4d-be73ff8a6785
# File already exists
# Count: 618
#
# 🚀 Starting processing of: TCGA-CM-4743-01Z-00-DX1.f54a6355-5623-498c-96b9-2ff1de6576c6.svs in folder: fbde56ab-b131-436e-8a6d-24c1e05217ca
# File already exists
# Count: 619
#
# 🚀 Starting processing of: TCGA-AG-A01L-01Z-00-DX1.1B54B139-4477-4E67-83D1-E431AA52F5B8.svs in folder: ff6b1378-16b5-4121-8abc-e30dd8bb54af
# File already exists
# Count: 620
#
# 🚀 Starting processing of: TCGA-AG-3731-01Z-00-DX1.9C30A84C-DD47-47C4-8899-3A1EF5153E1A.svs in folder: ff868863-d558-4e5d-b0f7-0f1dc7b21fe8
# ⚠️ Skipping TCGA-AG-3731-01Z-00-DX1.9C30A84C-DD47-47C4-8899-3A1EF5153E1A.svs: Not found or invalid in metadata.

# %% [markdown]
# ## Testing pipeline

# %%
import os

# Define your paths
h5_folder = r"D:\Aamir Gulzar\KSA_project2\dataset\Flat_directory\patches"
patch_data_folder = r"D:\Aamir Gulzar\KSA_project2\dataset\patch_data"

# Get list of .h5 files (without .h5 extension)
h5_files = [os.path.splitext(f)[0] for f in os.listdir(h5_folder) if f.endswith('.h5')]

# Get list of directory names in patch_data
patch_dirs = [d for d in os.listdir(patch_data_folder) if os.path.isdir(os.path.join(patch_data_folder, d))]

# Find .h5 files without corresponding directory
missing_dirs = [f + '.h5' for f in h5_files if f not in patch_dirs]

# Print results
print("Missing directories for the following .h5 files:")
for fname in missing_dirs:
    print(fname)
# Out:
# Missing directories for the following .h5 files:
# TCGA-QG-A5Z1-01Z-00-DX1.F3157C57-0F35-42D3-9CA5-C72D93F1BF89.h5
# TCGA-T9-A92H-01Z-00-DX2.43894C88-2096-4932-9E9D-17BDCACF988C.h5
# TCGA-T9-A92H-01Z-00-DX3.1DE7D5ED-60F7-4645-8243-AB0C027B3ED7.h5

# %%
import openslide
svs_path= "D:/Aamir Gulzar/WSI_Raw_data/ed5f8c30-29e3-4144-948b-b8658564f2d6/TCGA-3L-AA1B-01Z-00-DX1.8923A151-A690-40B7-9E5A-FCBEDFC2394F.svs"
# "D:\Aamir Gulzar\WSI_Raw_data\021821c9-68f3-4be3-97ec-4ade5b4aaa60\TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs"
slide = openslide.OpenSlide(svs_path)
magnification = slide.properties.get("openslide.objective-power")
slide.close()

if magnification:
    print(f"Magnification: {magnification}x")
    if magnification == "20":
        found_20x_path = svs_path
        
        print(f"✅ Found 200 magnification at: {found_20x_path}")
else:
    print(f"File: | Magnification info not found")
# Out:
# Magnification: 40x

# %%
# Load the SVS file
slide = openslide.OpenSlide(svs_path)

# Get dimensions of the base (level 0)
width, height = slide.dimensions
print(f"Base level dimensions: {width} x {height}")

# Get number of levels
level_count = slide.level_count
print(f"Number of levels: {level_count}")

# Print dimensions for each level
print("Level dimensions:")
for i in range(level_count):
    print(f" Level {i}: {slide.level_dimensions[i]}")

# Optional: print additional metadata
print("\nProperties:")
for key, value in slide.properties.items():
    print(f"{key}: {value}")
# Out:
# Base level dimensions: 95615 x 74462
# Number of levels: 4
# Level dimensions:
#  Level 0: (95615, 74462)
#  Level 1: (23903, 18615)
#  Level 2: (5975, 4653)
#  Level 3: (2987, 2326)
#
# Properties:
# aperio.AppMag: 40
# aperio.DSR ID: resc3-dsr1
# aperio.Date: 11/19/14
# aperio.DisplayColor: 0
# aperio.Exposure Scale: 0.000001
# aperio.Exposure Time: 109
# aperio.Filename: TCGA-3L-AA1B-01Z-00-DX1
# aperio.Focus Offset: 0.000000
# aperio.ICC Profile: ScanScope v1
# aperio.ImageID: 164819
# aperio.Left: 20.562956
# aperio.LineAreaXOffset: 0.011464
# aperio.LineAreaYOffset: -0.002805
# aperio.LineCameraSkew: -0.000153
# aperio.MPP: 0.2527
# aperio.OriginalHeight: 74562
# aperio.OriginalWidth: 97536
# aperio.Parmset: GOG136
# aperio.ScanScope ID: SS1764CNTLR
# aperio.StripeWidth: 2032
# aperio.Time: 17:24:10
# aperio.Time Zone: GMT-05:00
# aperio.Title: TCGA-3L-AA1B-01Z-00-DX1
# aperio.Top: 24.159639
# aperio.User: 79ba7f43-3d2d-48db-a92d-9bb62c29f510
# openslide.associated.thumbnail.height: 768
# openslide.associated.thumbnail.width: 986
# openslide.comment: Aperio Image Library v12.0.15
# 97536x74562 [0,100 95615x74462] (240x240) JPEG/RGB Q=30|AppMag = 40|StripeWidth = 2032|ScanScope ID = SS1764CNTLR|Filename = TCGA-3L-AA1B-01Z-00-DX1|Title = TCGA-3L-AA1B-01Z-00-DX1|Date = 11/19/14|Time = 17:24:10|Time Zone = GMT-05:00|User = 79ba7f43-3d2d-48db-a92d-9bb62c29f510|Parmset = GOG136|MPP = 0.2527|Left = 20.562956|Top = 24.159639|LineCameraSkew = -0.000153|LineAreaXOffset = 0.011464|LineAreaYOffset = -0.002805|Focus Offset = 0.000000|DSR ID = resc3-dsr1|ImageID = 164819|Exposure Time = 109|Exposure Scale = 0.000001|DisplayColor = 0|OriginalWidth = 97536|OriginalHeight = 74562|ICC Profile = ScanScope v1
# openslide.icc-size: 141992
# openslide.level-count: 4
# openslide.level[0].downsample: 1
# openslide.level[0].height: 74462
# openslide.level[0].tile-height: 240
# openslide.level[0].tile-width: 240
# openslide.level[0].width: 95615
# openslide.level[1].downsample: 4.0001164737474362
# openslide.level[1].height: 18615
# openslide.level[1].tile-height: 240
# openslide.level[1].tile-width: 240
# openslide.level[1].width: 23903
# openslide.level[2].downsample: 16.002759635885248
# openslide.level[2].height: 4653
# openslide.level[2].tile-height: 240
# openslide.level[2].tile-width: 240
# openslide.level[2].width: 5975
# openslide.level[3].downsample: 32.011637992205259
# openslide.level[3].height: 2326
# openslide.level[3].tile-height: 240
# openslide.level[3].tile-width: 240
# openslide.level[3].width: 2987
# openslide.mpp-x: 0.25269999999999998
# openslide.mpp-y: 0.25269999999999998
# openslide.objective-power: 40
# openslide.vendor: aperio
# tiff.ImageDescription: Aperio Image Library v12.0.15
# 97536x74562 [0,100 95615x74462] (240x240) JPEG/RGB Q=30|AppMag = 40|StripeWidth = 2032|ScanScope ID = SS1764CNTLR|Filename = TCGA-3L-AA1B-01Z-00-DX1|Title = TCGA-3L-AA1B-01Z-00-DX1|Date = 11/19/14|Time = 17:24:10|Time Zone = GMT-05:00|User = 79ba7f43-3d2d-48db-a92d-9bb62c29f510|Parmset = GOG136|MPP = 0.2527|Left = 20.562956|Top = 24.159639|LineCameraSkew = -0.000153|LineAreaXOffset = 0.011464|LineAreaYOffset = -0.002805|Focus Offset = 0.000000|DSR ID = resc3-dsr1|ImageID = 164819|Exposure Time = 109|Exposure Scale = 0.000001|DisplayColor = 0|OriginalWidth = 97536|OriginalHeight = 74562|ICC Profile = ScanScope v1
# tiff.ResolutionUnit: inch

# %% [markdown]
# ## Patches of orignal 40-20x each of 512

# %%
import os
import subprocess
from pathlib import Path
import openslide  # Ensure this is imported
# Define helper functions here: check_svs_file, rename_h5_file, create_patches_from_h5

# -------------------
# Define the full path to the specific .svs file you want to process
# found_20x_path = "D:/Aamir Gulzar/WSI_Raw_data/0ecb2d7b-0a69-46ce-80d6-1be65cec3cc7/TCGA-AA-3524-01Z-00-DX1.b1aae264-87be-4514-8f9d-25660b39caa7.svs"
found_20x_path=r"D:\Aamir Gulzar\WSI_Raw_data\02e1301c-1ee8-4853-9925-d01a1e7f7c3c\TCGA-AG-3581-01Z-00-DX1.2d8ba8ba-0533-41e5-b0e0-0d49ef408302.svs"

# Derived variables
flat_dir = "./FLAT_DIRECTORY"
svs_file = os.path.basename(found_20x_path)
source_dir = os.path.dirname(found_20x_path)

# Step 1: Check if it's a valid slide using metadata
bool_valid, label = check_svs_file(
    svs_file,
    "./slides_metadata/slide_metadata_filtered.csv",
    filename_column="Filename",
    label_column="Label"
)

if not bool_valid:
    print("❌ Slide not valid. Skipping.")
    exit()

newnameofsvs = f"{svs_file[:12]}_{label}"
print(f"✅ Slide is valid: {newnameofsvs}")

# Step 2: Determine magnification
slide = openslide.OpenSlide(found_20x_path)
mag = int(slide.properties.get("openslide.objective-power", 20))

if mag == 40:
    print("🔬 Magnification is 40x")
    patch_size = '1024'
    step_size = '1024'
else:
    print("🔬 Magnification is 20x")
    patch_size = '512'
    step_size = '512'

# Step 3: Run CLAM patch creation script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', patch_size,
    '--step_size', step_size,
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction command for {svs_file}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Step 4: Rename .h5 file
new_h5_path = rename_h5_file(svs_file, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed .h5 file: {new_h5_path}")

# Step 5: Create patches from .h5
base_dir = "./Patches"
sub_dir = f"{svs_file[:12]}_{label}"
output_dir = os.path.join(base_dir, sub_dir)
print(f"📦 Creating PNG patches in: {output_dir}")

# Optional: path for skipped patches CSV
svs_base_filename = os.path.splitext(svs_file)[0]
# full_path = Path("./FLAT_DIRECTORY/patches") / f"{svs_base_filename}skipped_patches.csv"

# If your `create_patches_from_h5` function requires that CSV, uncomment the next line and pass full_path
# create_patches_from_h5(new_h5_path, found_20x_path, output_dir, full_path, mag)

create_patches_from_h5(new_h5_path, found_20x_path, output_dir, mag)
# Out:
# ❌ Slide not valid. Skipping.
# ✅ Slide is valid: TCGA-AG-3581_None
# 🔬 Magnification is 20x
# 🚀 Running patch extraction command for TCGA-AG-3581-01Z-00-DX1.2d8ba8ba-0533-41e5-b0e0-0d49ef408302.svs
# Computed patch_level = 0 for 20x WSI (target 20x)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [01:28<00:00, 88.73s/it]
# 100%|##########| 1/1 [01:28<00:00, 88.73s/it]
#
#
# progress: 0.00, 0/1
# Creating patches for:  TCGA-AG-3581-01Z-00-DX1.2d8ba8ba-0533-41e5-b0e0-0d49ef408302 ...
# Total number of contours to process:  1
# Bounding Box: 26624 41984 50305 37825
# Contour Area: 1351756800.0
# Extracted 5337 coordinates
# 📦 Renamed H5: ./FLAT_DIRECTORY/patches\TCGA-AG-3581-01Z-00-DX1.2d8ba8ba-0533-41e5-b0e0-0d49ef408302.h5 → ./FLAT_DIRECTORY/patches\TCGA-AG-3581_None.h5
# ✅ Renamed .h5 file: ./FLAT_DIRECTORY/patches\TCGA-AG-3581_None.h5
# 📦 Creating PNG patches in: ./Patches\TCGA-AG-3581_None
# ✅ Done! Saved 5337 patches to ./Patches\TCGA-AG-3581_None
# 📄 Metadata CSV saved to: ./patches_metadata\TCGA-AG-3581_None.csv

# %% [markdown]
# ## Patches of orignal 10x from 20x each of 512

# %%
import os
import subprocess
from pathlib import Path
import openslide  # Ensure this is imported
# Define helper functions here: check_svs_file, rename_h5_file, create_patches_from_h5

# -------------------
# Define the full path to the specific .svs file you want to process
# found_20x_path = "D:/Aamir Gulzar/WSI_Raw_data/0ecb2d7b-0a69-46ce-80d6-1be65cec3cc7/TCGA-AA-3524-01Z-00-DX1.b1aae264-87be-4514-8f9d-25660b39caa7.svs"

# Derived variables
flat_dir = "./FLAT_DIRECTORY"
svs_file = os.path.basename(found_20x_path)
source_dir = os.path.dirname(found_20x_path)

# Step 1: Check if it's a valid slide using metadata
bool_valid, label = check_svs_file(
    svs_file,
    "./slides_metadata/slide_metadata_filtered.csv",
    filename_column="Filename",
    label_column="Label"
)

if not bool_valid:
    print("❌ Slide not valid. Skipping.")
    exit()

newnameofsvs = f"{svs_file[:12]}_{label}"
print(f"✅ Slide is valid: {newnameofsvs}")

# Step 2: Determine magnification
slide = openslide.OpenSlide(found_20x_path)
mag = int(slide.properties.get("openslide.objective-power", 20))

if mag == 40:
    print("🔬 Magnification is 40x")
    patch_size = '1024'
    step_size = '1024'
else:
    print("🔬 Magnification is 20x")
    patch_size = '512'
    step_size = '512'

# Step 3: Run CLAM patch creation script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', patch_size,
    '--step_size', step_size,
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction command for {svs_file}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Step 4: Rename .h5 file
new_h5_path = rename_h5_file(svs_file, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed .h5 file: {new_h5_path}")

# Step 5: Create patches from .h5
base_dir = "./Patches"
sub_dir = f"{svs_file[:12]}_{label}"
output_dir = os.path.join(base_dir, sub_dir)
print(f"📦 Creating PNG patches in: {output_dir}")

# Optional: path for skipped patches CSV
svs_base_filename = os.path.splitext(svs_file)[0]
# full_path = Path("./FLAT_DIRECTORY/patches") / f"{svs_base_filename}skipped_patches.csv"

# If your `create_patches_from_h5` function requires that CSV, uncomment the next line and pass full_path
# create_patches_from_h5(new_h5_path, found_20x_path, output_dir, full_path, mag)

create_patches_from_h5(new_h5_path, found_20x_path, output_dir, mag)

# %% [markdown]
# ## Clam with 40x each of patch size 512
#
# :/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60/TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs

# %%
import os
import subprocess
from pathlib import Path

# Path to the .svs file to test
# svs_path = found_20x_path
svs_path= "D:/Aamir Gulzar/WSI_Raw_data/9fc46b76-6d18-4268-9254-7476ae14f0d2/TCGA-A6-5667-01Z-00-DX1.1973b80d-b6b8-4ed8-9bc1-3aef51fbd9e6.svs"
svs_filename = os.path.basename(svs_path)
source_dir = os.path.dirname(svs_path)

# Label check (you must have this function and metadata file available)
bool_valid, label = check_svs_file(svs_filename, "./slides_metadata/slide_metadata_filtered.csv", filename_column="Filename", label_column="Label")
# if not bool_valid:
#     print("❌ SVS file is not valid or not labeled properly.")
# else:
#     print(f"✅ SVS file is valid. Label: {label}")
    
newnameofsvs = f"{svs_filename[:12]}_{label}"
flat_dir = "./FLAT_DIRECTORY"

# Create patches using CLAM script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', '512',
    '--step_size', '512',
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction for: {svs_filename}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Rename .h5 file
h5_path = rename_h5_file(svs_filename, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed h5 file: {h5_path}")

# Generate skipped patch filename
skipped_csv = Path("./FLAT_DIRECTORY/patches") / f"{os.path.splitext(svs_filename)[0]}_skipped_patches.csv"

# Create PNG patches from h5
png_patch_output_dir = os.path.join("./Patches", newnameofsvs)
print(f"🎨 Generating PNG patches in: {png_patch_output_dir}")
create_patches_from_h5(h5_path, svs_path, png_patch_output_dir)
# Out:
# 🚀 Running patch extraction for: TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# source:  D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# patch_save_dir:  ./FLAT_DIRECTORY\patches
# mask_save_dir:  ./FLAT_DIRECTORY\masks
# stitch_save_dir:  ./FLAT_DIRECTORY\stitches
# source : D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# save_dir : ./FLAT_DIRECTORY
# patch_save_dir : ./FLAT_DIRECTORY\patches
# mask_save_dir : ./FLAT_DIRECTORY\masks
# stitch_save_dir : ./FLAT_DIRECTORY\stitches
# {'seg_params': {'seg_level': -1, 'sthresh': 8, 'mthresh': 7, 'close': 4, 'use_otsu': False, 'keep_ids': 'none', 'exclude_ids': 'none'}, 'filter_params': {'a_t': 100, 'a_h': 16, 'max_n_holes': 8}, 'patch_params': {'use_padding': True, 'contour_fn': 'four_pt'}, 'vis_params': {'vis_level': -1, 'line_thickness': 250}}
# Computed patch_level = 0 for 40x WSI (target 20x)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:21<00:00, 21.64s/it]
# 100%|##########| 1/1 [00:21<00:00, 21.64s/it]
#
#
# progress: 0.00, 0/1
# processing TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# Creating patches for:  TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933 ...
# Total number of contours to process:  3
# Bounding Box: 1856 5799 10721 13106
# Contour Area: 101692208.0
# Extracted 411 coordinates
# Bounding Box: 101766 1473 10785 12786
# Contour Area: 102134208.0
# Extracted 415 coordinates
# Bounding Box: 51587 1121 10689 13010
# Contour Area: 102503808.0
# Extracted 420 coordinates
# segmentation took 0.13138842582702637 seconds
# patching took 21.505232572555542 seconds
# stitching took -1 seconds
# average segmentation time in s per slide: 0.13138842582702637
# average patching time in s per slide: 21.505232572555542
# average stiching time in s per slide: -1.0
# 📦 Renamed H5: ./FLAT_DIRECTORY/patches\TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.h5 → ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# ✅ Renamed h5 file: ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# 🎨 Generating PNG patches in: ./Patches\TCGA-AY-4070_nonMSIH
# ✅ Done! Saved 1246 patches to ./Patches\TCGA-AY-4070_nonMSIH

# %% [markdown]
# ## Clam with 10x each of patch size 512
#
# :/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60/TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs

# %%
import os
import subprocess
from pathlib import Path

# Path to the .svs file to test
# svs_path = found_20x_path
svs_filename = os.path.basename(svs_path)
source_dir = os.path.dirname(svs_path)

# Label check (you must have this function and metadata file available)
bool_valid, label = check_svs_file(svs_filename, "./slides_metadata/slide_metadata_filtered.csv", filename_column="Filename", label_column="Label")
# if not bool_valid:
#     print("❌ SVS file is not valid or not labeled properly.")
# else:
#     print(f"✅ SVS file is valid. Label: {label}")
    
newnameofsvs = f"{svs_filename[:12]}_{label}"
flat_dir = "./FLAT_DIRECTORY"

# Create patches using CLAM script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', '512',
    '--step_size', '512',
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction for: {svs_filename}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Rename .h5 file
h5_path = rename_h5_file(svs_filename, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed h5 file: {h5_path}")

# Generate skipped patch filename
skipped_csv = Path("./FLAT_DIRECTORY/patches") / f"{os.path.splitext(svs_filename)[0]}_skipped_patches.csv"

# Create PNG patches from h5
png_patch_output_dir = os.path.join("./Patches", newnameofsvs)
print(f"🎨 Generating PNG patches in: {png_patch_output_dir}")
create_patches_from_h5(h5_path, svs_path, png_patch_output_dir)
# Out:
# 🚀 Running patch extraction for: TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# source:  D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# patch_save_dir:  ./FLAT_DIRECTORY\patches
# mask_save_dir:  ./FLAT_DIRECTORY\masks
# stitch_save_dir:  ./FLAT_DIRECTORY\stitches
# source : D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# save_dir : ./FLAT_DIRECTORY
# patch_save_dir : ./FLAT_DIRECTORY\patches
# mask_save_dir : ./FLAT_DIRECTORY\masks
# stitch_save_dir : ./FLAT_DIRECTORY\stitches
# {'seg_params': {'seg_level': -1, 'sthresh': 8, 'mthresh': 7, 'close': 4, 'use_otsu': False, 'keep_ids': 'none', 'exclude_ids': 'none'}, 'filter_params': {'a_t': 100, 'a_h': 16, 'max_n_holes': 8}, 'patch_params': {'use_padding': True, 'contour_fn': 'four_pt'}, 'vis_params': {'vis_level': -1, 'line_thickness': 250}}
# Computed patch_level = 0 for 40x WSI (target 20x)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:04<00:00,  4.62s/it]
# 100%|##########| 1/1 [00:04<00:00,  4.62s/it]
#
#
# progress: 0.00, 0/1
# processing TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# Creating patches for:  TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933 ...
# Total number of contours to process:  3
# Bounding Box: 1856 5799 10721 13106
# Contour Area: 101692208.0
# Extracted 31 coordinates
# Bounding Box: 101766 1473 10785 12786
# Contour Area: 102134208.0
# Extracted 29 coordinates
# Bounding Box: 51587 1121 10689 13010
# Contour Area: 102503808.0
# Extracted 30 coordinates
# segmentation took 0.12940049171447754 seconds
# patching took 4.4848339557647705 seconds
# stitching took -1 seconds
# average segmentation time in s per slide: 0.12940049171447754
# average patching time in s per slide: 4.4848339557647705
# average stiching time in s per slide: -1.0
# 📦 Renamed H5: ./FLAT_DIRECTORY/patches\TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.h5 → ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# ✅ Renamed h5 file: ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# 🎨 Generating PNG patches in: ./Patches\TCGA-AY-4070_nonMSIH
# ✅ Done! Saved 90 patches to ./Patches\TCGA-AY-4070_nonMSIH

# %% [markdown]
# ## Patches with custom method

# %%
import os
import h5py
import openslide
from PIL import Image
import numpy as np
import cv2
import csv

def get_white_pixel_ratio(pil_img, satThresh=30, valThresh=200):
    if pil_img.mode != 'RGB':
        pil_img = pil_img.convert('RGB')

    img_np = np.array(pil_img, dtype=np.uint8)
    hsv_img = cv2.cvtColor(img_np, cv2.COLOR_RGB2HSV)

    # Mask: low saturation AND high brightness (value)
    sat_mask = hsv_img[:, :, 1] < satThresh
    val_mask = hsv_img[:, :, 2] > valThresh
    white_mask = np.logical_and(sat_mask, val_mask)

    return np.sum(white_mask) / white_mask.size

def create_patches_from_h5(h5_path, svs_path, output_dir, skip_log_path):
    os.makedirs(output_dir, exist_ok=True)

    BASE_PATCH_SIZE = 2048
    SUB_PATCH_SIZE = 512
    base_name = os.path.splitext(os.path.basename(h5_path))[0]

    with h5py.File(h5_path, 'r') as h5_file:
        coords = h5_file['coords'][:]

    slide = openslide.OpenSlide(svs_path)
    patch_count = 0

    log_exists = os.path.exists(skip_log_path)
    
    # ✅ Open log file in write mode and keep it open during patch loop
    with open(skip_log_path, 'a', newline='') as log_file:
        writer = csv.writer(log_file)
        if not log_exists:
            writer.writerow(["PatchName", "X", "Y", "WhiteRatio"])  # Write header only once

        for i, (x, y) in enumerate(coords):
            base_patch = slide.read_region((int(x), int(y)), 0, (BASE_PATCH_SIZE, BASE_PATCH_SIZE)).convert('RGB')

            for row in range(4):
                for col in range(4):
                    offset_x = col * SUB_PATCH_SIZE
                    offset_y = row * SUB_PATCH_SIZE

                    abs_x = int(x) + offset_x
                    abs_y = int(y) + offset_y

                    sub_patch = base_patch.crop((
                        offset_x, offset_y,
                        offset_x + SUB_PATCH_SIZE, offset_y + SUB_PATCH_SIZE
                    ))

                    white_ratio = get_white_pixel_ratio(sub_patch)
                    patch_name = f"{base_name}_x{abs_x}_y{abs_y}_patch{patch_count:05d}.png"

                    # if white_ratio > 0.8:
                    #     writer.writerow([patch_name, abs_x, abs_y, round(white_ratio, 4)])
                    #     continue

                    sub_patch.save(os.path.join(output_dir, patch_name))
                    patch_count += 1

    print(f"✅ Done! Saved {patch_count} coordinate-named 512x512 patches to {output_dir}")

# %% [markdown]
# ## Patches at 40x, each of 512 first and again 512

# %%
import os
import subprocess
from pathlib import Path

# Path to the .svs file to test
# svs_path = found_20x_path
svs_filename = os.path.basename(svs_path)
source_dir = os.path.dirname(svs_path)

# Label check (you must have this function and metadata file available)
bool_valid, label = check_svs_file(svs_filename, "./slides_metadata/slide_metadata_filtered.csv", filename_column="Filename", label_column="Label")
# if not bool_valid:
#     print("❌ SVS file is not valid or not labeled properly.")
# else:
#     print(f"✅ SVS file is valid. Label: {label}")
    
newnameofsvs = f"{svs_filename[:12]}_{label}"
flat_dir = "./FLAT_DIRECTORY"

# Create patches using CLAM script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', '512',
    '--step_size', '512',
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction for: {svs_filename}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Rename .h5 file
h5_path = rename_h5_file(svs_filename, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed h5 file: {h5_path}")

# Generate skipped patch filename
skipped_csv = Path("./FLAT_DIRECTORY/patches") / f"{os.path.splitext(svs_filename)[0]}_skipped_patches.csv"

# Create PNG patches from h5
png_patch_output_dir = os.path.join("./Patches", newnameofsvs)
print(f"🎨 Generating PNG patches in: {png_patch_output_dir}")
create_patches_from_h5(h5_path, svs_path, png_patch_output_dir, skipped_csv)
# Out:
# 🚀 Running patch extraction for: TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# source:  D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# patch_save_dir:  ./FLAT_DIRECTORY\patches
# mask_save_dir:  ./FLAT_DIRECTORY\masks
# stitch_save_dir:  ./FLAT_DIRECTORY\stitches
# source : D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# save_dir : ./FLAT_DIRECTORY
# patch_save_dir : ./FLAT_DIRECTORY\patches
# mask_save_dir : ./FLAT_DIRECTORY\masks
# stitch_save_dir : ./FLAT_DIRECTORY\stitches
# {'seg_params': {'seg_level': -1, 'sthresh': 8, 'mthresh': 7, 'close': 4, 'use_otsu': False, 'keep_ids': 'none', 'exclude_ids': 'none'}, 'filter_params': {'a_t': 100, 'a_h': 16, 'max_n_holes': 8}, 'patch_params': {'use_padding': True, 'contour_fn': 'four_pt'}, 'vis_params': {'vis_level': -1, 'line_thickness': 250}}
# Computed patch_level = 0 for 40x WSI (target 20x)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:21<00:00, 21.83s/it]
# 100%|##########| 1/1 [00:21<00:00, 21.83s/it]
#
#
# progress: 0.00, 0/1
# processing TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# Creating patches for:  TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933 ...
# Total number of contours to process:  3
# Bounding Box: 1856 5799 10721 13106
# Contour Area: 101692208.0
# Extracted 411 coordinates
# Bounding Box: 101766 1473 10785 12786
# Contour Area: 102134208.0
# Extracted 415 coordinates
# Bounding Box: 51587 1121 10689 13010
# Contour Area: 102503808.0
# Extracted 420 coordinates
# segmentation took 0.1293809413909912 seconds
# patching took 21.692877531051636 seconds
# stitching took -1 seconds
# average segmentation time in s per slide: 0.1293809413909912
# average patching time in s per slide: 21.692877531051636
# average stiching time in s per slide: -1.0
# 📦 Renamed H5: ./FLAT_DIRECTORY/patches\TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.h5 → ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# ✅ Renamed h5 file: ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# 🎨 Generating PNG patches in: ./Patches\TCGA-AY-4070_nonMSIH
# ✅ Done! Saved 1246 coordinate-named 512x512 patches to ./Patches\TCGA-AY-4070_nonMSIH

# %% [markdown]
# ## Patches at 20x, each of 1024 first and again 512

# %%
import os
import subprocess
from pathlib import Path

# Path to the .svs file to test
# svs_path = found_20x_path
svs_filename = os.path.basename(svs_path)
source_dir = os.path.dirname(svs_path)

# Label check (you must have this function and metadata file available)
bool_valid, label = check_svs_file(svs_filename, "./slides_metadata/slide_metadata_filtered.csv", filename_column="Filename", label_column="Label")
# if not bool_valid:
#     print("❌ SVS file is not valid or not labeled properly.")
# else:
#     print(f"✅ SVS file is valid. Label: {label}")
    
newnameofsvs = f"{svs_filename[:12]}_{label}"
flat_dir = "./FLAT_DIRECTORY"

# Create patches using CLAM script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', '1024',
    '--step_size', '1024',
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction for: {svs_filename}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Rename .h5 file
h5_path = rename_h5_file(svs_filename, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed h5 file: {h5_path}")

# Generate skipped patch filename
skipped_csv = Path("./FLAT_DIRECTORY/patches") / f"{os.path.splitext(svs_filename)[0]}_skipped_patches.csv"

# Create PNG patches from h5
png_patch_output_dir = os.path.join("./Patches", newnameofsvs)
print(f"🎨 Generating PNG patches in: {png_patch_output_dir}")
create_patches_from_h5(h5_path, svs_path, png_patch_output_dir, skipped_csv)
# Out:
# 🚀 Running patch extraction for: TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# source:  D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# patch_save_dir:  ./FLAT_DIRECTORY\patches
# mask_save_dir:  ./FLAT_DIRECTORY\masks
# stitch_save_dir:  ./FLAT_DIRECTORY\stitches
# source : D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# save_dir : ./FLAT_DIRECTORY
# patch_save_dir : ./FLAT_DIRECTORY\patches
# mask_save_dir : ./FLAT_DIRECTORY\masks
# stitch_save_dir : ./FLAT_DIRECTORY\stitches
# {'seg_params': {'seg_level': -1, 'sthresh': 8, 'mthresh': 7, 'close': 4, 'use_otsu': False, 'keep_ids': 'none', 'exclude_ids': 'none'}, 'filter_params': {'a_t': 100, 'a_h': 16, 'max_n_holes': 8}, 'patch_params': {'use_padding': True, 'contour_fn': 'four_pt'}, 'vis_params': {'vis_level': -1, 'line_thickness': 250}}
# Computed patch_level = 0 for 40x WSI (target 20x)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:21<00:00, 21.38s/it]
# 100%|##########| 1/1 [00:21<00:00, 21.38s/it]
#
#
# progress: 0.00, 0/1
# processing TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# Creating patches for:  TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933 ...
# Total number of contours to process:  3
# Bounding Box: 1856 5799 10721 13106
# Contour Area: 101692208.0
# Extracted 111 coordinates
# Bounding Box: 101766 1473 10785 12786
# Contour Area: 102134208.0
# Extracted 112 coordinates
# Bounding Box: 51587 1121 10689 13010
# Contour Area: 102503808.0
# Extracted 113 coordinates
# segmentation took 0.13060760498046875 seconds
# patching took 21.24550461769104 seconds
# stitching took -1 seconds
# average segmentation time in s per slide: 0.13060760498046875
# average patching time in s per slide: 21.24550461769104
# average stiching time in s per slide: -1.0
# 📦 Renamed H5: ./FLAT_DIRECTORY/patches\TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.h5 → ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# ✅ Renamed h5 file: ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# 🎨 Generating PNG patches in: ./Patches\TCGA-AY-4070_nonMSIH
# ✅ Done! Saved 1344 coordinate-named 512x512 patches to ./Patches\TCGA-AY-4070_nonMSIH

# %% [markdown]
# ## Patches at 20x, each of 1024 first and again 512 with white background filtering

# %%
create_patches_from_h5(h5_path, svs_path, png_patch_output_dir, skipped_csv)
# Out:
# ✅ Done! Saved 1169 coordinate-named 512x512 patches to ./Patches\TCGA-AY-4070_nonMSIH

# %% [markdown]
# ## Patches at 10x, each of 2048 first and again 512

# %%
import os
import subprocess
from pathlib import Path

# Path to the .svs file to test
# svs_path = found_20x_path
svs_filename = os.path.basename(svs_path)
source_dir = os.path.dirname(svs_path)

# Label check (you must have this function and metadata file available)
bool_valid, label = check_svs_file(svs_filename, "./slides_metadata/slide_metadata_filtered.csv", filename_column="Filename", label_column="Label")
# if not bool_valid:
#     print("❌ SVS file is not valid or not labeled properly.")
# else:
#     print(f"✅ SVS file is valid. Label: {label}")
    
newnameofsvs = f"{svs_filename[:12]}_{label}"
flat_dir = "./FLAT_DIRECTORY"

# Create patches using CLAM script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', '2048',
    '--step_size', '2048',
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction for: {svs_filename}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Rename .h5 file
h5_path = rename_h5_file(svs_filename, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed h5 file: {h5_path}")

# Generate skipped patch filename
skipped_csv = Path("./FLAT_DIRECTORY/patches") / f"{os.path.splitext(svs_filename)[0]}_skipped_patches.csv"

# Create PNG patches from h5
png_patch_output_dir = os.path.join("./Patches", newnameofsvs)
print(f"🎨 Generating PNG patches in: {png_patch_output_dir}")
create_patches_from_h5(h5_path, svs_path, png_patch_output_dir, skipped_csv)
# Out:
# 🚀 Running patch extraction for: TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# source:  D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# patch_save_dir:  ./FLAT_DIRECTORY\patches
# mask_save_dir:  ./FLAT_DIRECTORY\masks
# stitch_save_dir:  ./FLAT_DIRECTORY\stitches
# source : D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# save_dir : ./FLAT_DIRECTORY
# patch_save_dir : ./FLAT_DIRECTORY\patches
# mask_save_dir : ./FLAT_DIRECTORY\masks
# stitch_save_dir : ./FLAT_DIRECTORY\stitches
# {'seg_params': {'seg_level': -1, 'sthresh': 8, 'mthresh': 7, 'close': 4, 'use_otsu': False, 'keep_ids': 'none', 'exclude_ids': 'none'}, 'filter_params': {'a_t': 100, 'a_h': 16, 'max_n_holes': 8}, 'patch_params': {'use_padding': True, 'contour_fn': 'four_pt'}, 'vis_params': {'vis_level': -1, 'line_thickness': 250}}
# Computed patch_level = 0 for 40x WSI (target 20x)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:22<00:00, 22.28s/it]
# 100%|##########| 1/1 [00:22<00:00, 22.28s/it]
#
#
# progress: 0.00, 0/1
# processing TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# Creating patches for:  TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933 ...
# Total number of contours to process:  3
# Bounding Box: 1856 5799 10721 13106
# Contour Area: 101692208.0
# Extracted 31 coordinates
# Bounding Box: 101766 1473 10785 12786
# Contour Area: 102134208.0
# Extracted 29 coordinates
# Bounding Box: 51587 1121 10689 13010
# Contour Area: 102503808.0
# Extracted 30 coordinates
# segmentation took 0.13111162185668945 seconds
# patching took 22.14188528060913 seconds
# stitching took -1 seconds
# average segmentation time in s per slide: 0.13111162185668945
# average patching time in s per slide: 22.14188528060913
# average stiching time in s per slide: -1.0
# 📦 Renamed H5: ./FLAT_DIRECTORY/patches\TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.h5 → ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# ✅ Renamed h5 file: ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# 🎨 Generating PNG patches in: ./Patches\TCGA-AY-4070_nonMSIH
# ✅ Done! Saved 1440 coordinate-named 512x512 patches to ./Patches\TCGA-AY-4070_nonMSIH

# %% [markdown]
# ## creating patches of one 512x512 from 1024

# %%
def create_patches_from_h5(h5_path, svs_path, output_dir):
    os.makedirs(output_dir, exist_ok=True)

    PATCH_SIZE = 1024
    
    # Extract base name from h5 file (without extension)
    base_name = os.path.splitext(os.path.basename(h5_path))[0]
    
    # Load coordinates
    with h5py.File(h5_path, 'r') as h5_file:
        coords = h5_file['coords'][:]  # shape (N, 2), each row is (x, y)
    
    # Open the WSI
    slide = openslide.OpenSlide(svs_path)
    
    # Extract and save patches
    for i, (x, y) in enumerate(coords):
        patch = slide.read_region((int(x), int(y)), 0, (PATCH_SIZE, PATCH_SIZE)).convert('RGB')
        
        # Filename format: [basename]_x[y]_y[y]_patch[i].png
        patch_name = f"{base_name}_x{int(x)}_y{int(y)}_patch{i:05d}.png"
        patch.save(os.path.join(output_dir, patch_name))
    
    print(f"✅ Done! Saved {len(coords)} patches to {output_dir}")

# %%
import os
import subprocess
from pathlib import Path

# Path to the .svs file to test
# svs_path = found_20x_path
svs_filename = os.path.basename(svs_path)
source_dir = os.path.dirname(svs_path)

# Label check (you must have this function and metadata file available)
bool_valid, label = check_svs_file(svs_filename, "./slides_metadata/slide_metadata_filtered.csv", filename_column="Filename", label_column="Label")
# if not bool_valid:
#     print("❌ SVS file is not valid or not labeled properly.")
# else:
#     print(f"✅ SVS file is valid. Label: {label}")
    
newnameofsvs = f"{svs_filename[:12]}_{label}"
flat_dir = "./FLAT_DIRECTORY"

# Create patches using CLAM script
command = [
    'python', './CLAM/create_patches_fp.py',
    '--source', source_dir,
    '--save_dir', flat_dir,
    '--patch_size', '1024',
    '--step_size', '1024',
    '--seg', '--patch'
]

print(f"🚀 Running patch extraction for: {svs_filename}")
with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True) as proc:
    for line in proc.stdout:
        print(line, end='')

# Rename .h5 file
h5_path = rename_h5_file(svs_filename, label, h5_dir="./FLAT_DIRECTORY/patches")
print(f"✅ Renamed h5 file: {h5_path}")

# Generate skipped patch filename
skipped_csv = Path("./FLAT_DIRECTORY/patches") / f"{os.path.splitext(svs_filename)[0]}_skipped_patches.csv"

# Create PNG patches from h5
png_patch_output_dir = os.path.join("./Patches", newnameofsvs)
print(f"🎨 Generating PNG patches in: {png_patch_output_dir}")
create_patches_from_h5(h5_path, svs_path, png_patch_output_dir)
# Out:
# 🚀 Running patch extraction for: TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# source:  D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# patch_save_dir:  ./FLAT_DIRECTORY\patches
# mask_save_dir:  ./FLAT_DIRECTORY\masks
# stitch_save_dir:  ./FLAT_DIRECTORY\stitches
# source : D:/Aamir Gulzar/WSI_Raw_data/021821c9-68f3-4be3-97ec-4ade5b4aaa60
# save_dir : ./FLAT_DIRECTORY
# patch_save_dir : ./FLAT_DIRECTORY\patches
# mask_save_dir : ./FLAT_DIRECTORY\masks
# stitch_save_dir : ./FLAT_DIRECTORY\stitches
# {'seg_params': {'seg_level': -1, 'sthresh': 8, 'mthresh': 7, 'close': 4, 'use_otsu': False, 'keep_ids': 'none', 'exclude_ids': 'none'}, 'filter_params': {'a_t': 100, 'a_h': 16, 'max_n_holes': 8}, 'patch_params': {'use_padding': True, 'contour_fn': 'four_pt'}, 'vis_params': {'vis_level': -1, 'line_thickness': 250}}
# Computed patch_level = 0 for 40x WSI (target 20x)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:21<00:00, 21.21s/it]
# 100%|##########| 1/1 [00:21<00:00, 21.21s/it]
#
#
# progress: 0.00, 0/1
# processing TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.svs
# Creating patches for:  TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933 ...
# Total number of contours to process:  3
# Bounding Box: 1856 5799 10721 13106
# Contour Area: 101692208.0
# Extracted 111 coordinates
# Bounding Box: 101766 1473 10785 12786
# Contour Area: 102134208.0
# Extracted 112 coordinates
# Bounding Box: 51587 1121 10689 13010
# Contour Area: 102503808.0
# Extracted 113 coordinates
# segmentation took 0.12823891639709473 seconds
# patching took 21.077141284942627 seconds
# stitching took -1 seconds
# average segmentation time in s per slide: 0.12823891639709473
# average patching time in s per slide: 21.077141284942627
# average stiching time in s per slide: -1.0
# 📦 Renamed H5: ./FLAT_DIRECTORY/patches\TCGA-AY-4070-01Z-00-DX1.dd650ac6-8480-4fd8-85b8-15a7840a5933.h5 → ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# ✅ Renamed h5 file: ./FLAT_DIRECTORY/patches\TCGA-AY-4070_nonMSIH.h5
# 🎨 Generating PNG patches in: ./Patches\TCGA-AY-4070_nonMSIH
# ✅ Done! Saved 336 patches to ./Patches\TCGA-AY-4070_nonMSIH

# %%
from PIL import Image
import os
from tqdm import tqdm

# --- Paths ---
input_dir = './Patches/TCGA-AY-4070_nonMSIH/'   # e.g., "./patches_40x"
output_dir = './Patches/path_to_save_512x512_patches'    # e.g., "./patches_20x"

# Create output dir if not exists
os.makedirs(output_dir, exist_ok=True)

# --- Resize all patches ---
for fname in tqdm(os.listdir(input_dir)):
    if fname.endswith(".png"):
        input_path = os.path.join(input_dir, fname)
        output_path = os.path.join(output_dir, fname)

        # Open and resize image
        img = Image.open(input_path)
        img_resized = img.resize((512, 512), resample=Image.BICUBIC)

        # Save resized image
        img_resized.save(output_path)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 336/336 [00:21<00:00, 15.82it/s]

# %% [markdown]
# ## Testing levels of downsample

# %%
import os
import subprocess
from pathlib import Path

# Top-level directory containing subfolders with .svs files
wsi_root = "D:/Aamir Gulzar/WSI_Raw_data"
flat_dir = "./FLAT_DIRECTORY"
count=0

# Loop through all subfolders
for subdir in os.listdir(wsi_root):
    # if count==2:
    #     break
    # count+=1
    full_subdir_path = os.path.join(wsi_root, subdir)
    if not os.path.isdir(full_subdir_path):
        continue  # skip non-folder items

    # Search for .svs file in this subfolder
    svs_files = [f for f in os.listdir(full_subdir_path) if f.endswith('.svs')]
    if not svs_files:
        print(f"❌ No .svs file found in: {full_subdir_path}")
        continue
    else:
        print(svs_files)

    # If multiple .svs files exist, process each one
    for svs_file in svs_files:

        bool_valid, label= is_valid_svs_file(svs_file)

        # print(bool_valid)
        source_dir = full_subdir_path
        source_dir_quoted = f"{source_dir}"
        flat_dir_quoted = f"{flat_dir}"
        output_dir= "./FLAT_DIRECTORY/downsampled"
        target_size = (1024, 1024)
        svs_path = os.path.join(source_dir_quoted, svs_file)

        print(f"🚀 Processing: {svs_file} in {subdir}")
        level= downsample_and_resize_wsi(svs_path, output_dir, target_size, label)
        print(f"level: {level}\n")

# %%
new_h5_path= rename_h5_file(svs_file, label, h5_dir="./FLAT_DIRECTORY/patches")
base_dir = "./FLAT_DIRECTORY"
sub_dir = "patches"

# Create full path
print(new_h5_path)
base_dir= "./Patches"
sub_dir= f"{svs_file[:12]}_{label}"
output_dir = os.path.join(base_dir, sub_dir) 
print(output_dir)
create_patches_from_h5(new_h5_path, svs_path, output_dir)
